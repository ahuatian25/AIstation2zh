# %% [markdown]
# 实验T1：考虑时间问题，对AllTrain（AllTest为0）进行按时排序，前50%训练，后50%测试。

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import keras

from keras import layers,metrics
from keras.optimizers import RMSprop
from keras.layers import Dense, LSTM, Dropout, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import PReLU, ELU
from keras.models import Sequential, load_model
from keras.utils import np_utils, multi_gpu_model

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder 
from sklearn.utils import shuffle as reset
from sklearn.model_selection import train_test_split,GridSearchCV,StratifiedShuffleSplit
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import log_loss,make_scorer

from matplotlib.colors import LogNorm
# import 
from matplotlib.pylab import plt
from copy import deepcopy
from datetime import datetime
from imblearn.over_sampling import RandomOverSampler #https://imbalanced-learn.org/stable/generated/imblearn.over_sampling.RandomOverSampler.html?highlight=randomoversampler
from frplayer import FilterResponseNormalization

# %%
def train_test_split_DataFrame(data, test_size=0.2, considerTime=True, random_state=None):
    # ConsiderTime-------trainDF和testDF分割时是否考虑时间问题，即是否需要随机打乱。True:按照‘Dates’列进行降序排列,False：随机打乱样本的顺序，
    if considerTime:
        data=data.sort_values(by="Dates", ascending=True)
    else:
        data=reset(data, random_state=random_state)
    train=data[int(len(data)*test_size):].reset_index(drop=True)
    test=data[:int(len(data)*test_size)].reset_index(drop=True)
    return train, test

# %%
def parse_time(x):
    DD=datetime.strptime(x,"%Y-%m-%d %H:%M")#zj    
    time=DD.hour#*60+DD.minute
    day=DD.day
    month=DD.month
    year=DD.year
    return time,day,month,year
def Dates2TDMY(x):
    DD=datetime.strptime(x,"%Y-%m-%d %H:%M")#zj  
    time=DD.hour#*60+DD.minute
    day=DD.day
    month=DD.month
    year=DD.year
    #T_D_M_Y=str(time)+str(day)+str(month)+str(year)
    T_D_M_Y=str(time)+str(day)+str(month)
    return T_D_M_Y
def get_season(x):
    summer=0
    fall=0
    winter=0
    spring=0
    if (x in [5, 6, 7]):
        summer=1
    if (x in [8, 9, 10]):
        fall=1
    if (x in [11, 0, 1]):
        winter=1
    if (x in [2, 3, 4]):
        spring=1
    return summer, fall, winter, spring

# %%
def field2Vec(trainDF,testDF,fieldStr):
    fields=sorted(trainDF[fieldStr].unique())
    categories=sorted(trainDF["Category"].unique())
    C_counts=trainDF.groupby(["Category"]).size()
    F_C_counts=trainDF.groupby([fieldStr,"Category"]).size()
    F_counts=trainDF.groupby([fieldStr]).size()
    logodds={}
    logoddsPF={}
    MIN_CAT_COUNTS=2
    default_logodds=np.log(C_counts/len(trainDF))-np.log(1.0-C_counts/float(len(trainDF)))
    for f in fields:
        PA=F_counts[f]/float(len(trainDF))
        logoddsPF[f]=np.log(PA)-np.log(1.-PA)
        logodds[f]=deepcopy(default_logodds)
        for cat in F_C_counts[f].keys():
            if (F_C_counts[f][cat]>MIN_CAT_COUNTS) and F_C_counts[f][cat]<F_counts[f]:
                PA=F_C_counts[f][cat]/float(F_counts[f])
                logodds[f][categories.index(cat)]=np.log(PA)-np.log(1.0-PA)
        logodds[f]=pd.Series(logodds[f])
        logodds[f].index=range(len(categories))
    ########此部分代码，从逻辑上不应该出现在此处，但是为了编程的方便，放在了此处#########
    #fieldsTest=sorted(testDF[fieldStr].unique())
    #N_count=0
    #for f in fieldsTest:
        #if f not in fields:
            #logoddsPF[f]=-50.0  #np.log(0.)-np.log(1.)=-inf,便于计算，改为-99999.0
            #logodds[f]=deepcopy(default_logodds)
            #pa=1.0/float(len(categories))
            #logodds[f][range(len(categories))]=np.log(pa)-np.log(1.0-pa)
            #logodds[f]=pd.Series(logodds[f])
            #logodds[f].index=range(len(categories))
            #N_count=N_count+1
    #print(fieldStr+' N_count: '+str(N_count))
    ########此部分代码，从逻辑上不应该出现在此处，但是为了编程的方便，放在了此处#########
    #引进代码原作者的新思想
    if testDF.shape[0]>0: #如果testDF里有样本,......
        print('There are some new:'+fieldStr)
        new_fields=sorted(testDF[fieldStr].unique())
        new_F_counts=testDF.groupby(fieldStr).size()
        only_new=set(new_fields+fields)-set(fields)
        only_old=set(new_fields+fields)-set(new_fields)
        in_both=set(new_fields).intersection(fields)
        print('# only_new_fieldds:'+str(len(only_new)))
        for f in only_new:
            PA=new_F_counts[f]/float(len(testDF)+len(trainDF))
            logoddsPF[f]=np.log(PA)-np.log(1.-PA)
            logodds[f]=deepcopy(default_logodds)
            logodds[f].index=range(len(categories))
        for f in in_both:
            PA=(F_counts[f]+new_F_counts[f])/float(len(testDF)+len(trainDF))
            logoddsPF[f]=np.log(PA)-np.log(1.-PA)    
    return logodds,logoddsPF

# %%
def parse_data(df,logodds_A,logoddsPF_A,logodds_T,logoddsPF_T,needT_D_M_Y=False):
    feature_list=df.columns.tolist()
    if "Descript" in feature_list:
        feature_list.remove("Descript")
    if "Resolution" in feature_list:
        feature_list.remove("Resolution")
    if "Category" in feature_list:
        feature_list.remove("Category")
    if "Id" in feature_list:
        feature_list.remove("Id")

    cleanData=df[feature_list]
    cleanData.index=range(len(df))
    print("Creating address features")###Creating address features###
    address_features=cleanData["Address"].apply(lambda x: logodds_A[x])
    address_features.columns=["logodds_A"+str(x) for x in range(len(address_features.columns))]
    if needT_D_M_Y:
        print("Creating time T_D_M_Y features")###Creating time T_D_M_Y features###
        T_D_M_Y_features=cleanData["T_D_M_Y"].apply(lambda xx: logodds_T[xx])
        T_D_M_Y_features.columns=["logodds_T"+str(xx) for xx in range(len(T_D_M_Y_features.columns))]

    print("Parsing dates")            ###Creating address features###
    cleanData["Time"], cleanData["Day"], cleanData["Month"], cleanData["Year"]=zip(*cleanData["Dates"].apply(parse_time))
    #     dummy_ranks_DAY = pd.get_dummies(cleanData['DayOfWeek'], prefix='DAY')
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    #     cleanData["DayOfWeek"]=cleanData["DayOfWeek"].apply(lambda x: days.index(x)/float(len(days)))
    print("Creating one-hot variables")
    dummy_ranks_PD = pd.get_dummies(cleanData['PdDistrict'], prefix='PD')
    dummy_ranks_DAY = pd.get_dummies(cleanData["DayOfWeek"], prefix='DAY')
    cleanData["IsInterection"]=cleanData["Address"].apply(lambda x: 1 if "/" in x else 0)
    cleanData["logoddsPF_A"]=cleanData["Address"].apply(lambda x: logoddsPF_A[x])
    if needT_D_M_Y:
        cleanData["logoddsPF_T"]=cleanData["T_D_M_Y"].apply(lambda x: logoddsPF_T[x])
    print("droping processed columns")
    cleanData=cleanData.drop("PdDistrict",axis=1)
    cleanData=cleanData.drop("DayOfWeek",axis=1)
    cleanData=cleanData.drop("Address",axis=1)    
    cleanData=cleanData.drop("Dates",axis=1)
    if needT_D_M_Y:
        cleanData=cleanData.drop("T_D_M_Y",axis=1)
    feature_list=cleanData.columns.tolist()
    print("joining one-hot features")
    if needT_D_M_Y:
        features = cleanData[feature_list].join(dummy_ranks_PD.iloc[:,:]).join(dummy_ranks_DAY.iloc[:,:]).join(address_features.iloc[:,:]).join(T_D_M_Y_features.iloc[:,:])
    else:
        features = cleanData[feature_list].join(dummy_ranks_PD.iloc[:,:]).join(dummy_ranks_DAY.iloc[:,:]).join(address_features.iloc[:,:])
    print("creating new features")
    features["IsDup"]=pd.Series(features.duplicated()|features.duplicated(keep='last')).apply(int)
    features["Awake"]=features["Time"].apply(lambda x: 1 if (x==0 or (x>=8 and x<=23)) else 0)
    features["Summer"], features["Fall"], features["Winter"], features["Spring"]=zip(*features["Month"].apply(get_season))
    if "Category" in df.columns:
        labels = df["Category"].astype('category')
    else:
        labels=None
    return features,labels

# %%
def generator(X, Y, lookback, delay, min_index, max_index, shuffle=False, batch_size=128, step=6):
    if max_index is None:
        max_index = len(X) - delay - 1
    i = min_index + lookback
    while 1:
        if shuffle:
            rows = np.random.randint(min_index + lookback, max_index, size=batch_size)
        else:
            if i + batch_size >= max_index:
                i = min_index + lookback
            rows = np.arange(i, min(i + batch_size, max_index))
            i += len(rows)

        samples = np.zeros((len(rows), lookback // step, X.shape[-1]))
        targets = np.zeros((len(rows),Y.shape[1]))
        for j, row in enumerate(rows):
            indices = range(rows[j] - lookback, rows[j], step)
            samples[j] = X[indices]
            targets[j] = Y[rows[j]+delay]
        yield samples, targets
    #Now here is the data generator that we will use. It yields a tuple (samples, targets) where samples is one batch of input data and targets is the corresponding array of target temperatures. It takes the following arguments:
        # •data: The original array of floating point data, which we just normalized in the code snippet above.
        # •lookback: How many timesteps back should our input data go.
        # •delay: How many timesteps in the future should our target be.
        # •min_index and max_index: Indices in the data array that delimit which timesteps to draw from. This is useful for keeping a segment of the data for validation and another one for testing.
        # •shuffle: Whether to shuffle our samples or draw them in chronological order.
        # •batch_size: The number of samples per batch.
        # •step: The period, in timesteps, at which we sample data. We will set it 6 in order to draw one data point every hour.

# %%
#Import data
ConsiderTime=True#False# True##trainDF和testDF分割时是否考虑时间问题，即是否需要随机打乱。True:按照‘Dates’列进行降序排列,False：随机打乱样本的顺序，
Rate_ALL=0.0 #0.0即不保留测试机
needOverSampler=False
needT_D_M_Y=True #False  使用_T_D_M_Y和周几
allDF=pd.read_csv("./HuZhou.csv")
print('The shape of OrginalAllDF: '+str(allDF.shape))

xy_scaler=preprocessing.StandardScaler()
xy_scaler.fit(allDF[["X","Y"]])
allDF[["X","Y"]]=xy_scaler.transform(allDF[["X","Y"]])
allDF=allDF[abs(allDF["Y"])<100]
allDF.index=range(len(allDF))
print('The shape of AllDF after del wrong X and Y values: '+str(allDF.shape))

def listCat(x):
    return list(x)
allDF.drop_duplicates(inplace=True,subset=['Dates', 'DayOfWeek', 'PdDistrict', 'Address', 'X', 'Y', 'Category'])
Train_duplicated=pd.pivot_table(allDF,index=['Dates','DayOfWeek','PdDistrict', 'Address', 'X', 'Y'], values='Category',aggfunc=[len,listCat])
print('The shape of AllDF after drop_duplicates: '+str(allDF.shape))
print(Train_duplicated.shape)

trainDF,testDF=train_test_split_DataFrame(allDF, test_size=Rate_ALL, considerTime=ConsiderTime, random_state=None)
print('Address_counts_allDF_trainDF_testDF: ' + str(len(allDF["Address"].unique())) + '_'+ str(len(trainDF["Address"].unique())) + '_' + str(len(testDF["Address"].unique())))

N_AllSample=allDF.shape[0]
N_AllTrain=trainDF.shape[0]
N_AllTest=testDF.shape[0]
N_CLASS=len(allDF["Category"].unique())
print('The # of AllDF, AllTrain, AllTest, is: '+str(N_AllSample)+','+str(N_AllTrain)+','+str(N_AllTest))
#################Now proceed as before#################
print('-----------LOGOODS: Address-------------')
logodds_A,logoddsPF_A=field2Vec(trainDF,testDF,"Address")
if needT_D_M_Y:
    trainDF["T_D_M_Y"]=trainDF["Dates"].apply(Dates2TDMY)
    trainDF["T_D_M_Y"]=trainDF["T_D_M_Y"]+trainDF["DayOfWeek"]
    if Rate_ALL>0:
        testDF[["X","Y"]]=xy_scaler.transform(testDF[["X","Y"]])
        testDF["T_D_M_Y"]=testDF["Dates"].apply(Dates2TDMY)
        testDF["T_D_M_Y"]=testDF["T_D_M_Y"]+testDF["DayOfWeek"]
    print('-----------LOGOODS: T_D_M_Y-------------')
    logodds_T,logoddsPF_T=field2Vec(trainDF,testDF,"T_D_M_Y")    
else:
    logodds_T=None
    logoddsPF_T=None
    
print('-----------LOGOODS: parse_data of Alltrain  -------------')
features, labels=parse_data(trainDF,logodds_A,logoddsPF_A,logodds_T,logoddsPF_T,needT_D_M_Y) 
if Rate_ALL>0:
    print('-----------LOGOODS: parse_data of Alltest  -------------')
    features_test, labels_test=parse_data(testDF,logodds_A,logoddsPF_A,logodds_T,logoddsPF_T,needT_D_M_Y)###########和训练集使用同样的时间和地点Logoodds值#####
    x_test=features_test.values
    y_test=labels_test.values
    y_test = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_test)), num_classes=N_CLASS)

print(features.columns.tolist())
print(len(features.columns))

collist=features.columns.tolist()
scaler = preprocessing.StandardScaler()
scaler.fit(features)
features[collist]=scaler.transform(features)
if Rate_ALL>0:
    features_test[collist]=scaler.transform(features_test)###########和训练集使用同样的scaler值#####
######################################################
#############################先进行过采样，然后再根据时间来排序##################################
if needOverSampler:
    print('------------RandomOverSampler--------------')
    ros = RandomOverSampler()
    featuresArrayOverSampler, labelsArrayOverSampler = ros.fit_resample(features.values,labels.values)#####过采样#####
    N_AllTrain_OverSampler=int(featuresArrayOverSampler.shape[0])
    print('Shape of OverSampler of AllTrain: '+str(featuresArrayOverSampler.shape))
else:
    featuresArrayOverSampler=features.values
    labelsArrayOverSampler=labels.values
    N_AllTrain_OverSampler=int(featuresArrayOverSampler.shape[0])
    print('------------Attention: we do not RandomOverSampler---------------')
if ConsiderTime:
    #####按照年（第6列）月（第5列）日（第4列）时（第3列）排序
    print('------------ConsiderTime:  Sorting--------------')
    time_temp=featuresArrayOverSampler[:,2]+np.dot(featuresArrayOverSampler[:,3],100)+np.dot(featuresArrayOverSampler[:,4],10000)+np.dot(featuresArrayOverSampler[:,5],1000000)
    features_label_time=np.column_stack((featuresArrayOverSampler,labelsArrayOverSampler))
    features_label_time=np.column_stack((features_label_time,time_temp))
    features_label_time =features_label_time[np.argsort(features_label_time[:,-1])]
    labelsArrayOverSampler=features_label_time[:,-2]
    featuresArrayOverSampler=features_label_time[:,0:featuresArrayOverSampler.shape[1]]
    del features_label_time
    #############################先进行过采样，然后再根据时间来排序----结束############################
if Rate_ALL>0:
    print('------------RandomOverSampler for AllTest--------------')
    ros = RandomOverSampler()
    featuresArray_test, labelsArray_test = ros.fit_resample(features_test.values,labels_test.values)#####过采样#####
    N_AllTest_OverSampler=int(featuresArray_test.shape[0])
    labelsArray_test = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(labelsArray_test)), num_classes=N_CLASS)
    print('Shape of OverSampler of AllTest: '+str(featuresArray_test.shape))
# Out:
# The shape of OrginalAllDF: (145962, 9)
# The shape of AllDF after del wrong X and Y values: (145960, 9)
# The shape of AllDF after drop_duplicates: (145876, 9)
# (145859, 2)
# Address_counts_allDF_trainDF_testDF: 17161_17161_0
# The # of AllDF, AllTrain, AllTest, is: 145876,145876,0
# -----------LOGOODS: Address-------------
# -----------LOGOODS: T_D_M_Y-------------
# -----------LOGOODS: parse_data of Alltrain  -------------
# Creating address features
# Creating time T_D_M_Y features
# Parsing dates
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Creating one-hot variables
# droping processed columns
# joining one-hot features
# creating new features
# ['X', 'Y', 'Time', 'Day', 'Month', 'Year', 'IsInterection', 'logoddsPF_A', 'logoddsPF_T', 'PD_星期一', 'PD_星期三', 'PD_星期二', 'PD_星期五', 'PD_星期六', 'PD_星期四', 'PD_星期日', 'DAY_星期一', 'DAY_星期三', 'DAY_星期二', 'DAY_星期五', 'DAY_星期六', 'DAY_星期四', 'DAY_星期日', 'logodds_A0', 'logodds_A1', 'logodds_A2', 'logodds_A3', 'logodds_A4', 'logodds_A5', 'logodds_A6', 'logodds_A7', 'logodds_A8', 'logodds_A9', 'logodds_A10', 'logodds_A11', 'logodds_A12', 'logodds_A13', 'logodds_A14', 'logodds_A15', 'logodds_A16', 'logodds_A17', 'logodds_A18', 'logodds_A19', 'logodds_A20', 'logodds_A21', 'logodds_A22', 'logodds_A23', 'logodds_A24', 'logodds_A25', 'logodds_A26', 'logodds_A27', 'logodds_A28', 'logodds_A29', 'logodds_A30', 'logodds_A31', 'logodds_A32', 'logodds_A33', 'logodds_A34', 'logodds_A35', 'logodds_A36', 'logodds_A37', 'logodds_A38', 'logodds_A39', 'logodds_A40', 'logodds_A41', 'logodds_A42', 'logodds_A43', 'logodds_A44', 'logodds_A45', 'logodds_A46', 'logodds_A47', 'logodds_A48', 'logodds_A49', 'logodds_T0', 'logodds_T1', 'logodds_T2', 'logodds_T3', 'logodds_T4', 'logodds_T5', 'logodds_T6', 'logodds_T7', 'logodds_T8', 'logodds_T9', 'logodds_T10', 'logodds_T11', 'logodds_T12', 'logodds_T13', 'logodds_T14', 'logodds_T15', 'logodds_T16', 'logodds_T17', 'logodds_T18', 'logodds_T19', 'logodds_T20', 'logodds_T21', 'logodds_T22', 'logodds_T23', 'logodds_T24', 'logodds_T25', 'logodds_T26', 'logodds_T27', 'logodds_T28', 'logodds_T29', 'logodds_T30', 'logodds_T31', 'logodds_T32', 'logodds_T33', 'logodds_T34', 'logodds_T35', 'logodds_T36', 'logodds_T37', 'logodds_T38', 'logodds_T39', 'logodds_T40', 'logodds_T41', 'logodds_T42', 'logodds_T43', 'logodds_T44', 'logodds_T45', 'logodds_T46', 'logodds_T47', 'logodds_T48', 'logodds_T49', 'IsDup', 'Awake', 'Summer', 'Fall', 'Winter', 'Spring']
# 129
# ------------Attention: we do not RandomOverSampler---------------
# ------------ConsiderTime:  Sorting--------------

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=20
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=64
dp=0.5
Rate_Val=0.5
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])
if ConsiderTime:
    print('--------Spllit train val according to time!---------')
    x_train=featuresArrayOverSampler[0:N_Train_OverSampler,:]
    y_train=labelsArrayOverSampler[0:N_Train_OverSampler]
    x_val=featuresArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler,:]
    y_val=labelsArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler]
else:
    x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)

# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####

y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
# model.save('jjs_model_0124V3.h5')
# Out:
# ------------Building DNN model--------------
# --------Spllit train val according to time!---------
# ------------DNN Training Go! Go! Go!!!!-----------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 72938 samples, validate on 72938 samples
# Epoch 1/20
#  - 22s - loss: 1.7090 - accuracy: 0.5743 - top_k_categorical_accuracy: 0.8543 - val_loss: 1.5505 - val_accuracy: 0.5621 - val_top_k_categorical_accuracy: 0.8932
# Epoch 2/20
#  - 19s - loss: 1.4121 - accuracy: 0.6034 - top_k_categorical_accuracy: 0.9039 - val_loss: 1.5357 - val_accuracy: 0.5671 - val_top_k_categorical_accuracy: 0.8960
# Epoch 3/20
#  - 18s - loss: 1.3876 - accuracy: 0.6066 - top_k_categorical_accuracy: 0.9077 - val_loss: 1.5177 - val_accuracy: 0.5713 - val_top_k_categorical_accuracy: 0.8946
# Epoch 4/20
#  - 19s - loss: 1.3728 - accuracy: 0.6079 - top_k_categorical_accuracy: 0.9097 - val_loss: 1.5231 - val_accuracy: 0.5725 - val_top_k_categorical_accuracy: 0.8960
# Epoch 5/20
#  - 20s - loss: 1.3611 - accuracy: 0.6102 - top_k_categorical_accuracy: 0.9110 - val_loss: 1.5367 - val_accuracy: 0.5677 - val_top_k_categorical_accuracy: 0.8905
# Epoch 6/20
#  - 19s - loss: 1.3524 - accuracy: 0.6110 - top_k_categorical_accuracy: 0.9121 - val_loss: 1.5351 - val_accuracy: 0.5701 - val_top_k_categorical_accuracy: 0.8904
# Epoch 7/20
#  - 20s - loss: 1.3436 - accuracy: 0.6120 - top_k_categorical_accuracy: 0.9135 - val_loss: 1.5425 - val_accuracy: 0.5683 - val_top_k_categorical_accuracy: 0.8894
# Epoch 8/20
#  - 19s - loss: 1.3339 - accuracy: 0.6133 - top_k_categorical_accuracy: 0.9155 - val_loss: 1.5663 - val_accuracy: 0.5645 - val_top_k_categorical_accuracy: 0.8838
# Epoch 9/20
#  - 20s - loss: 1.3272 - accuracy: 0.6137 - top_k_categorical_accuracy: 0.9169 - val_loss: 1.5524 - val_accuracy: 0.5689 - val_top_k_categorical_accuracy: 0.8910
# Epoch 10/20
#  - 20s - loss: 1.3184 - accuracy: 0.6155 - top_k_categorical_accuracy: 0.9165 - val_loss: 1.6061 - val_accuracy: 0.5571 - val_top_k_categorical_accuracy: 0.8798
# Epoch 11/20
#  - 21s - loss: 1.3116 - accuracy: 0.6155 - top_k_categorical_accuracy: 0.9176 - val_loss: 1.6087 - val_accuracy: 0.5602 - val_top_k_categorical_accuracy: 0.8774
# Epoch 12/20
#  - 19s - loss: 1.3037 - accuracy: 0.6172 - top_k_categorical_accuracy: 0.9193 - val_loss: 1.6020 - val_accuracy: 0.5625 - val_top_k_categorical_accuracy: 0.8813
# Epoch 13/20
#  - 20s - loss: 1.2965 - accuracy: 0.6176 - top_k_categorical_accuracy: 0.9201 - val_loss: 1.6313 - val_accuracy: 0.5513 - val_top_k_categorical_accuracy: 0.8747
# Epoch 14/20
#  - 19s - loss: 1.2893 - accuracy: 0.6190 - top_k_categorical_accuracy: 0.9216 - val_loss: 1.6224 - val_accuracy: 0.5575 - val_top_k_categorical_accuracy: 0.8776
# Epoch 15/20
#  - 20s - loss: 1.2822 - accuracy: 0.6182 - top_k_categorical_accuracy: 0.9230 - val_loss: 1.6223 - val_accuracy: 0.5604 - val_top_k_categorical_accuracy: 0.8757
# Epoch 16/20
#  - 18s - loss: 1.2755 - accuracy: 0.6210 - top_k_categorical_accuracy: 0.9233 - val_loss: 1.6830 - val_accuracy: 0.5400 - val_top_k_categorical_accuracy: 0.8691
# Epoch 17/20
#  - 18s - loss: 1.2713 - accuracy: 0.6209 - top_k_categorical_accuracy: 0.9249 - val_loss: 1.6786 - val_accuracy: 0.5453 - val_top_k_categorical_accuracy: 0.8701
# Epoch 18/20
#  - 18s - loss: 1.2644 - accuracy: 0.6219 - top_k_categorical_accuracy: 0.9258 - val_loss: 1.6764 - val_accuracy: 0.5530 - val_top_k_categorical_accuracy: 0.8718
# Epoch 19/20
#  - 19s - loss: 1.2577 - accuracy: 0.6235 - top_k_categorical_accuracy: 0.9274 - val_loss: 1.7140 - val_accuracy: 0.5424 - val_top_k_categorical_accuracy: 0.8628
# Epoch 20/20
#  - 21s - loss: 1.2510 - accuracy: 0.6240 - top_k_categorical_accuracy: 0.9278 - val_loss: 1.7156 - val_accuracy: 0.5375 - val_top_k_categorical_accuracy: 0.8611

# %%
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS8.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC8.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC8.png')
plt.show()

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=20
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=64
dp=0.5
Rate_Val=0.2
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])
if ConsiderTime:
    print('--------Spllit train val according to time!---------')
    x_train=featuresArrayOverSampler[0:N_Train_OverSampler,:]
    y_train=labelsArrayOverSampler[0:N_Train_OverSampler]
    x_val=featuresArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler,:]
    y_val=labelsArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler]
else:
    x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)

# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####

y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
# model.save('jjs_model_0124V3.h5')
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS8.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC8.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC8.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# --------Spllit train val according to time!---------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 116701 samples, validate on 29175 samples
# Epoch 1/20
#  - 26s - loss: 1.6308 - accuracy: 0.5751 - top_k_categorical_accuracy: 0.8695 - val_loss: 8.2124 - val_accuracy: 7.8835e-04 - val_top_k_categorical_accuracy: 0.0149
# Epoch 2/20
#  - 31s - loss: 1.4272 - accuracy: 0.5945 - top_k_categorical_accuracy: 0.9042 - val_loss: 8.6967 - val_accuracy: 5.8269e-04 - val_top_k_categorical_accuracy: 0.0162
# Epoch 3/20
#  - 25s - loss: 1.4086 - accuracy: 0.5979 - top_k_categorical_accuracy: 0.9063 - val_loss: 8.9996 - val_accuracy: 0.0014 - val_top_k_categorical_accuracy: 0.0174
# Epoch 4/20
#  - 25s - loss: 1.3970 - accuracy: 0.5993 - top_k_categorical_accuracy: 0.9079 - val_loss: 9.3227 - val_accuracy: 0.0014 - val_top_k_categorical_accuracy: 0.0167
# Epoch 5/20
#  - 25s - loss: 1.3886 - accuracy: 0.6013 - top_k_categorical_accuracy: 0.9085 - val_loss: 9.2518 - val_accuracy: 5.8269e-04 - val_top_k_categorical_accuracy: 0.0148
# Epoch 6/20
#  - 26s - loss: 1.3812 - accuracy: 0.6013 - top_k_categorical_accuracy: 0.9092 - val_loss: 9.3602 - val_accuracy: 8.2262e-04 - val_top_k_categorical_accuracy: 0.0133
# Epoch 7/20
#  - 27s - loss: 1.3743 - accuracy: 0.6028 - top_k_categorical_accuracy: 0.9097 - val_loss: 9.4996 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0170
# Epoch 8/20
#  - 30s - loss: 1.3667 - accuracy: 0.6031 - top_k_categorical_accuracy: 0.9115 - val_loss: 9.4084 - val_accuracy: 0.0017 - val_top_k_categorical_accuracy: 0.0167
# Epoch 9/20
#  - 27s - loss: 1.3604 - accuracy: 0.6049 - top_k_categorical_accuracy: 0.9116 - val_loss: 10.0705 - val_accuracy: 7.1979e-04 - val_top_k_categorical_accuracy: 0.0143
# Epoch 10/20
#  - 25s - loss: 1.3538 - accuracy: 0.6053 - top_k_categorical_accuracy: 0.9128 - val_loss: 9.8474 - val_accuracy: 7.1979e-04 - val_top_k_categorical_accuracy: 0.0155
# Epoch 11/20
#  - 28s - loss: 1.3496 - accuracy: 0.6052 - top_k_categorical_accuracy: 0.9134 - val_loss: 10.4991 - val_accuracy: 0.0012 - val_top_k_categorical_accuracy: 0.0167
# Epoch 12/20
#  - 26s - loss: 1.3442 - accuracy: 0.6062 - top_k_categorical_accuracy: 0.9146 - val_loss: 10.0080 - val_accuracy: 7.8835e-04 - val_top_k_categorical_accuracy: 0.0162
# Epoch 13/20
#  - 28s - loss: 1.3388 - accuracy: 0.6068 - top_k_categorical_accuracy: 0.9155 - val_loss: 10.2519 - val_accuracy: 0.0018 - val_top_k_categorical_accuracy: 0.0178
# Epoch 14/20
#  - 31s - loss: 1.3345 - accuracy: 0.6081 - top_k_categorical_accuracy: 0.9156 - val_loss: 10.2305 - val_accuracy: 9.2545e-04 - val_top_k_categorical_accuracy: 0.0152
# Epoch 15/20
#  - 32s - loss: 1.3292 - accuracy: 0.6080 - top_k_categorical_accuracy: 0.9169 - val_loss: 10.7511 - val_accuracy: 0.0012 - val_top_k_categorical_accuracy: 0.0156
# Epoch 16/20
#  - 31s - loss: 1.3246 - accuracy: 0.6088 - top_k_categorical_accuracy: 0.9174 - val_loss: 10.3756 - val_accuracy: 7.8835e-04 - val_top_k_categorical_accuracy: 0.0149
# Epoch 17/20
#  - 29s - loss: 1.3202 - accuracy: 0.6089 - top_k_categorical_accuracy: 0.9183 - val_loss: 10.4014 - val_accuracy: 0.0012 - val_top_k_categorical_accuracy: 0.0179
# Epoch 18/20
#  - 28s - loss: 1.3158 - accuracy: 0.6096 - top_k_categorical_accuracy: 0.9186 - val_loss: 11.1976 - val_accuracy: 0.0013 - val_top_k_categorical_accuracy: 0.0161
# Epoch 19/20
#  - 31s - loss: 1.3131 - accuracy: 0.6109 - top_k_categorical_accuracy: 0.9197 - val_loss: 11.1444 - val_accuracy: 9.5973e-04 - val_top_k_categorical_accuracy: 0.0165
# Epoch 20/20
#  - 30s - loss: 1.3092 - accuracy: 0.6112 - top_k_categorical_accuracy: 0.9197 - val_loss: 10.9047 - val_accuracy: 0.0013 - val_top_k_categorical_accuracy: 0.0177

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=20
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=64
dp=0.5
Rate_Val=0.8
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])
if ConsiderTime:
    print('--------Spllit train val according to time!---------')
    x_train=featuresArrayOverSampler[0:N_Train_OverSampler,:]
    y_train=labelsArrayOverSampler[0:N_Train_OverSampler]
    x_val=featuresArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler,:]
    y_val=labelsArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler]
else:
    x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)

# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####

y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
# model.save('jjs_model_0124V3.h5')
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS8.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC8.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC8.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# --------Spllit train val according to time!---------
# ------------DNN Training Go! Go! Go!!!!-----------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 29175 samples, validate on 116701 samples
# Epoch 1/20
#  - 17s - loss: 2.0813 - accuracy: 0.5402 - top_k_categorical_accuracy: 0.7950 - val_loss: 6.2977 - val_accuracy: 0.0415 - val_top_k_categorical_accuracy: 0.3035
# Epoch 2/20
#  - 15s - loss: 1.4520 - accuracy: 0.5968 - top_k_categorical_accuracy: 0.9002 - val_loss: 6.7122 - val_accuracy: 0.0507 - val_top_k_categorical_accuracy: 0.3041
# Epoch 3/20
#  - 15s - loss: 1.4128 - accuracy: 0.6027 - top_k_categorical_accuracy: 0.9039 - val_loss: 7.5831 - val_accuracy: 0.0505 - val_top_k_categorical_accuracy: 0.3017
# Epoch 4/20
#  - 15s - loss: 1.3891 - accuracy: 0.6056 - top_k_categorical_accuracy: 0.9082 - val_loss: 8.1743 - val_accuracy: 0.0441 - val_top_k_categorical_accuracy: 0.2984
# Epoch 5/20
#  - 14s - loss: 1.3712 - accuracy: 0.6097 - top_k_categorical_accuracy: 0.9103 - val_loss: 8.7593 - val_accuracy: 0.0446 - val_top_k_categorical_accuracy: 0.2979
# Epoch 6/20
#  - 14s - loss: 1.3547 - accuracy: 0.6096 - top_k_categorical_accuracy: 0.9126 - val_loss: 8.7346 - val_accuracy: 0.0511 - val_top_k_categorical_accuracy: 0.2987
# Epoch 7/20
#  - 14s - loss: 1.3415 - accuracy: 0.6119 - top_k_categorical_accuracy: 0.9140 - val_loss: 9.4166 - val_accuracy: 0.0518 - val_top_k_categorical_accuracy: 0.2995
# Epoch 8/20
#  - 13s - loss: 1.3267 - accuracy: 0.6137 - top_k_categorical_accuracy: 0.9167 - val_loss: 9.8086 - val_accuracy: 0.0557 - val_top_k_categorical_accuracy: 0.3005
# Epoch 9/20
#  - 16s - loss: 1.3122 - accuracy: 0.6145 - top_k_categorical_accuracy: 0.9183 - val_loss: 10.1974 - val_accuracy: 0.0471 - val_top_k_categorical_accuracy: 0.2996
# Epoch 10/20
#  - 15s - loss: 1.2990 - accuracy: 0.6177 - top_k_categorical_accuracy: 0.9201 - val_loss: 10.5361 - val_accuracy: 0.0499 - val_top_k_categorical_accuracy: 0.2978
# Epoch 11/20
#  - 13s - loss: 1.2862 - accuracy: 0.6187 - top_k_categorical_accuracy: 0.9230 - val_loss: 10.6585 - val_accuracy: 0.0462 - val_top_k_categorical_accuracy: 0.2963
# Epoch 12/20
#  - 13s - loss: 1.2725 - accuracy: 0.6219 - top_k_categorical_accuracy: 0.9256 - val_loss: 11.0083 - val_accuracy: 0.0562 - val_top_k_categorical_accuracy: 0.3032
# Epoch 13/20
#  - 14s - loss: 1.2592 - accuracy: 0.6248 - top_k_categorical_accuracy: 0.9275 - val_loss: 11.6618 - val_accuracy: 0.0543 - val_top_k_categorical_accuracy: 0.2973
# Epoch 14/20
#  - 15s - loss: 1.2483 - accuracy: 0.6233 - top_k_categorical_accuracy: 0.9283 - val_loss: 11.9837 - val_accuracy: 0.0456 - val_top_k_categorical_accuracy: 0.2996
# Epoch 15/20
#  - 14s - loss: 1.2347 - accuracy: 0.6261 - top_k_categorical_accuracy: 0.9314 - val_loss: 11.9695 - val_accuracy: 0.0488 - val_top_k_categorical_accuracy: 0.2986
# Epoch 16/20
#  - 14s - loss: 1.2196 - accuracy: 0.6312 - top_k_categorical_accuracy: 0.9349 - val_loss: 11.9195 - val_accuracy: 0.0589 - val_top_k_categorical_accuracy: 0.2987
# Epoch 17/20
#  - 13s - loss: 1.2127 - accuracy: 0.6309 - top_k_categorical_accuracy: 0.9358 - val_loss: 12.2276 - val_accuracy: 0.0500 - val_top_k_categorical_accuracy: 0.3006
# Epoch 18/20
#  - 15s - loss: 1.1985 - accuracy: 0.6338 - top_k_categorical_accuracy: 0.9372 - val_loss: 12.2600 - val_accuracy: 0.0548 - val_top_k_categorical_accuracy: 0.2948
# Epoch 19/20
#  - 15s - loss: 1.1870 - accuracy: 0.6372 - top_k_categorical_accuracy: 0.9381 - val_loss: 12.5026 - val_accuracy: 0.0593 - val_top_k_categorical_accuracy: 0.3021
# Epoch 20/20
#  - 15s - loss: 1.1757 - accuracy: 0.6363 - top_k_categorical_accuracy: 0.9395 - val_loss: 12.7678 - val_accuracy: 0.0574 - val_top_k_categorical_accuracy: 0.2947

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=20
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=64
dp=0.5
Rate_Val=0.3
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])
if ConsiderTime:
    print('--------Spllit train val according to time!---------')
    x_train=featuresArrayOverSampler[0:N_Train_OverSampler,:]
    y_train=labelsArrayOverSampler[0:N_Train_OverSampler]
    x_val=featuresArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler,:]
    y_val=labelsArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler]
else:
    x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)

# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####

y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
# model.save('jjs_model_0124V3.h5')
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS8.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC8.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC8.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# --------Spllit train val according to time!---------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 102113 samples, validate on 43763 samples
# Epoch 1/20
#  - 28s - loss: 1.6406 - accuracy: 0.5755 - top_k_categorical_accuracy: 0.8670 - val_loss: 4.5432 - val_accuracy: 0.0722 - val_top_k_categorical_accuracy: 0.3512
# Epoch 2/20
#  - 29s - loss: 1.4174 - accuracy: 0.5984 - top_k_categorical_accuracy: 0.9056 - val_loss: 4.5894 - val_accuracy: 0.0820 - val_top_k_categorical_accuracy: 0.3519
# Epoch 3/20
#  - 33s - loss: 1.3994 - accuracy: 0.6021 - top_k_categorical_accuracy: 0.9066 - val_loss: 4.5275 - val_accuracy: 0.0981 - val_top_k_categorical_accuracy: 0.3500
# Epoch 4/20
#  - 29s - loss: 1.3885 - accuracy: 0.6024 - top_k_categorical_accuracy: 0.9088 - val_loss: 4.5603 - val_accuracy: 0.0905 - val_top_k_categorical_accuracy: 0.3547
# Epoch 5/20
#  - 30s - loss: 1.3788 - accuracy: 0.6037 - top_k_categorical_accuracy: 0.9098 - val_loss: 4.5683 - val_accuracy: 0.0841 - val_top_k_categorical_accuracy: 0.3519
# Epoch 6/20
#  - 35s - loss: 1.3693 - accuracy: 0.6049 - top_k_categorical_accuracy: 0.9109 - val_loss: 4.6031 - val_accuracy: 0.0896 - val_top_k_categorical_accuracy: 0.3540
# Epoch 7/20
#  - 35s - loss: 1.3636 - accuracy: 0.6063 - top_k_categorical_accuracy: 0.9117 - val_loss: 4.5417 - val_accuracy: 0.1008 - val_top_k_categorical_accuracy: 0.3466
# Epoch 8/20
#  - 28s - loss: 1.3567 - accuracy: 0.6073 - top_k_categorical_accuracy: 0.9126 - val_loss: 4.6414 - val_accuracy: 0.0961 - val_top_k_categorical_accuracy: 0.3651
# Epoch 9/20
#  - 32s - loss: 1.3505 - accuracy: 0.6082 - top_k_categorical_accuracy: 0.9137 - val_loss: 4.6478 - val_accuracy: 0.0760 - val_top_k_categorical_accuracy: 0.3639
# Epoch 10/20
#  - 35s - loss: 1.3450 - accuracy: 0.6094 - top_k_categorical_accuracy: 0.9140 - val_loss: 4.7268 - val_accuracy: 0.0972 - val_top_k_categorical_accuracy: 0.3518
# Epoch 11/20
#  - 36s - loss: 1.3373 - accuracy: 0.6095 - top_k_categorical_accuracy: 0.9151 - val_loss: 4.5920 - val_accuracy: 0.0842 - val_top_k_categorical_accuracy: 0.3729
# Epoch 12/20
#  - 27s - loss: 1.3310 - accuracy: 0.6109 - top_k_categorical_accuracy: 0.9165 - val_loss: 4.8263 - val_accuracy: 0.0868 - val_top_k_categorical_accuracy: 0.3576
# Epoch 13/20
#  - 26s - loss: 1.3266 - accuracy: 0.6105 - top_k_categorical_accuracy: 0.9177 - val_loss: 4.7118 - val_accuracy: 0.0882 - val_top_k_categorical_accuracy: 0.3745
# Epoch 14/20
#  - 26s - loss: 1.3192 - accuracy: 0.6125 - top_k_categorical_accuracy: 0.9186 - val_loss: 4.6763 - val_accuracy: 0.0906 - val_top_k_categorical_accuracy: 0.3694
# Epoch 15/20
#  - 26s - loss: 1.3155 - accuracy: 0.6125 - top_k_categorical_accuracy: 0.9190 - val_loss: 4.7679 - val_accuracy: 0.0919 - val_top_k_categorical_accuracy: 0.3595
# Epoch 16/20
#  - 24s - loss: 1.3093 - accuracy: 0.6129 - top_k_categorical_accuracy: 0.9198 - val_loss: 4.6669 - val_accuracy: 0.0888 - val_top_k_categorical_accuracy: 0.3782
# Epoch 17/20
#  - 26s - loss: 1.3058 - accuracy: 0.6134 - top_k_categorical_accuracy: 0.9201 - val_loss: 4.7024 - val_accuracy: 0.1060 - val_top_k_categorical_accuracy: 0.3596
# Epoch 18/20
#  - 25s - loss: 1.3007 - accuracy: 0.6144 - top_k_categorical_accuracy: 0.9210 - val_loss: 4.9009 - val_accuracy: 0.0832 - val_top_k_categorical_accuracy: 0.3672
# Epoch 19/20
#  - 26s - loss: 1.2967 - accuracy: 0.6143 - top_k_categorical_accuracy: 0.9219 - val_loss: 4.8999 - val_accuracy: 0.0855 - val_top_k_categorical_accuracy: 0.3642
# Epoch 20/20
#  - 29s - loss: 1.2929 - accuracy: 0.6158 - top_k_categorical_accuracy: 0.9227 - val_loss: 4.8771 - val_accuracy: 0.0842 - val_top_k_categorical_accuracy: 0.3642

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=20
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=64
dp=0.5
Rate_Val=0.4
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])
if ConsiderTime:
    print('--------Spllit train val according to time!---------')
    x_train=featuresArrayOverSampler[0:N_Train_OverSampler,:]
    y_train=labelsArrayOverSampler[0:N_Train_OverSampler]
    x_val=featuresArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler,:]
    y_val=labelsArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler]
else:
    x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)

# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####

y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
# model.save('jjs_model_0124V3.h5')
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS8.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC8.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC8.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# --------Spllit train val according to time!---------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 87526 samples, validate on 58350 samples
# Epoch 1/20
#  - 25s - loss: 1.6745 - accuracy: 0.5761 - top_k_categorical_accuracy: 0.8620 - val_loss: 1.5393 - val_accuracy: 0.5647 - val_top_k_categorical_accuracy: 0.8963
# Epoch 2/20
#  - 21s - loss: 1.4171 - accuracy: 0.6006 - top_k_categorical_accuracy: 0.9043 - val_loss: 1.5309 - val_accuracy: 0.5641 - val_top_k_categorical_accuracy: 0.8978
# Epoch 3/20
#  - 22s - loss: 1.3950 - accuracy: 0.6032 - top_k_categorical_accuracy: 0.9063 - val_loss: 1.5233 - val_accuracy: 0.5643 - val_top_k_categorical_accuracy: 0.8959
# Epoch 4/20
#  - 23s - loss: 1.3814 - accuracy: 0.6053 - top_k_categorical_accuracy: 0.9078 - val_loss: 1.5141 - val_accuracy: 0.5681 - val_top_k_categorical_accuracy: 0.8970
# Epoch 5/20
#  - 23s - loss: 1.3722 - accuracy: 0.6065 - top_k_categorical_accuracy: 0.9100 - val_loss: 1.5171 - val_accuracy: 0.5673 - val_top_k_categorical_accuracy: 0.8968
# Epoch 6/20
#  - 22s - loss: 1.3628 - accuracy: 0.6083 - top_k_categorical_accuracy: 0.9110 - val_loss: 1.5242 - val_accuracy: 0.5672 - val_top_k_categorical_accuracy: 0.8960
# Epoch 7/20
#  - 23s - loss: 1.3553 - accuracy: 0.6098 - top_k_categorical_accuracy: 0.9119 - val_loss: 1.5266 - val_accuracy: 0.5698 - val_top_k_categorical_accuracy: 0.8931
# Epoch 8/20
#  - 23s - loss: 1.3472 - accuracy: 0.6114 - top_k_categorical_accuracy: 0.9135 - val_loss: 1.5288 - val_accuracy: 0.5680 - val_top_k_categorical_accuracy: 0.8921
# Epoch 9/20
#  - 22s - loss: 1.3398 - accuracy: 0.6107 - top_k_categorical_accuracy: 0.9146 - val_loss: 1.5417 - val_accuracy: 0.5625 - val_top_k_categorical_accuracy: 0.8926
# Epoch 10/20
#  - 21s - loss: 1.3324 - accuracy: 0.6123 - top_k_categorical_accuracy: 0.9153 - val_loss: 1.5343 - val_accuracy: 0.5663 - val_top_k_categorical_accuracy: 0.8926
# Epoch 11/20
#  - 21s - loss: 1.3255 - accuracy: 0.6135 - top_k_categorical_accuracy: 0.9157 - val_loss: 1.5584 - val_accuracy: 0.5624 - val_top_k_categorical_accuracy: 0.8884
# Epoch 12/20
#  - 22s - loss: 1.3184 - accuracy: 0.6138 - top_k_categorical_accuracy: 0.9173 - val_loss: 1.5751 - val_accuracy: 0.5622 - val_top_k_categorical_accuracy: 0.8840
# Epoch 13/20
#  - 21s - loss: 1.3122 - accuracy: 0.6146 - top_k_categorical_accuracy: 0.9180 - val_loss: 1.5730 - val_accuracy: 0.5626 - val_top_k_categorical_accuracy: 0.8867
# Epoch 14/20
#  - 22s - loss: 1.3056 - accuracy: 0.6166 - top_k_categorical_accuracy: 0.9188 - val_loss: 1.5676 - val_accuracy: 0.5631 - val_top_k_categorical_accuracy: 0.8875
# Epoch 15/20
#  - 21s - loss: 1.2993 - accuracy: 0.6165 - top_k_categorical_accuracy: 0.9200 - val_loss: 1.5918 - val_accuracy: 0.5553 - val_top_k_categorical_accuracy: 0.8822
# Epoch 16/20
#  - 20s - loss: 1.2922 - accuracy: 0.6164 - top_k_categorical_accuracy: 0.9213 - val_loss: 1.5877 - val_accuracy: 0.5595 - val_top_k_categorical_accuracy: 0.8837
# Epoch 17/20
#  - 22s - loss: 1.2883 - accuracy: 0.6171 - top_k_categorical_accuracy: 0.9222 - val_loss: 1.6075 - val_accuracy: 0.5544 - val_top_k_categorical_accuracy: 0.8793
# Epoch 18/20
#  - 21s - loss: 1.2816 - accuracy: 0.6173 - top_k_categorical_accuracy: 0.9226 - val_loss: 1.6184 - val_accuracy: 0.5566 - val_top_k_categorical_accuracy: 0.8786
# Epoch 19/20
#  - 29s - loss: 1.2774 - accuracy: 0.6181 - top_k_categorical_accuracy: 0.9238 - val_loss: 1.6246 - val_accuracy: 0.5556 - val_top_k_categorical_accuracy: 0.8774
# Epoch 20/20
#  - 29s - loss: 1.2712 - accuracy: 0.6204 - top_k_categorical_accuracy: 0.9244 - val_loss: 1.6149 - val_accuracy: 0.5562 - val_top_k_categorical_accuracy: 0.8806

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=20
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=64
dp=0.5
Rate_Val=1000.0/(87526+58350)
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])
if ConsiderTime:
    print('--------Spllit train val according to time!---------')
    x_train=featuresArrayOverSampler[0:N_Train_OverSampler,:]
    y_train=labelsArrayOverSampler[0:N_Train_OverSampler]
    x_val=featuresArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler,:]
    y_val=labelsArrayOverSampler[N_Train_OverSampler:N_AllTrain_OverSampler]
else:
    x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)

# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####

y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
# model.save('jjs_model_0124V3.h5')
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS8.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC8.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC8.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# --------Spllit train val according to time!---------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 144876 samples, validate on 1000 samples
# Epoch 1/20
#  - 30s - loss: 1.6154 - accuracy: 0.5706 - top_k_categorical_accuracy: 0.8745 - val_loss: 7.1497 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 2/20
#  - 29s - loss: 1.4397 - accuracy: 0.5888 - top_k_categorical_accuracy: 0.9025 - val_loss: 7.3628 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 3/20
#  - 31s - loss: 1.4212 - accuracy: 0.5911 - top_k_categorical_accuracy: 0.9058 - val_loss: 7.7556 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 4/20
#  - 30s - loss: 1.4108 - accuracy: 0.5922 - top_k_categorical_accuracy: 0.9064 - val_loss: 7.7988 - val_accuracy: 0.0020 - val_top_k_categorical_accuracy: 0.0050
# Epoch 5/20
#  - 33s - loss: 1.4018 - accuracy: 0.5937 - top_k_categorical_accuracy: 0.9078 - val_loss: 7.5284 - val_accuracy: 0.0020 - val_top_k_categorical_accuracy: 0.0050
# Epoch 6/20
#  - 32s - loss: 1.3955 - accuracy: 0.5946 - top_k_categorical_accuracy: 0.9081 - val_loss: 7.6114 - val_accuracy: 0.0020 - val_top_k_categorical_accuracy: 0.0050
# Epoch 7/20
#  - 31s - loss: 1.3889 - accuracy: 0.5965 - top_k_categorical_accuracy: 0.9095 - val_loss: 7.6587 - val_accuracy: 0.0020 - val_top_k_categorical_accuracy: 0.0050
# Epoch 8/20
#  - 30s - loss: 1.3841 - accuracy: 0.5965 - top_k_categorical_accuracy: 0.9101 - val_loss: 7.6805 - val_accuracy: 0.0020 - val_top_k_categorical_accuracy: 0.0050
# Epoch 9/20
#  - 30s - loss: 1.3772 - accuracy: 0.5974 - top_k_categorical_accuracy: 0.9114 - val_loss: 7.8989 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 10/20
#  - 32s - loss: 1.3726 - accuracy: 0.5979 - top_k_categorical_accuracy: 0.9112 - val_loss: 7.8911 - val_accuracy: 0.0020 - val_top_k_categorical_accuracy: 0.0050
# Epoch 11/20
#  - 32s - loss: 1.3671 - accuracy: 0.5987 - top_k_categorical_accuracy: 0.9120 - val_loss: 7.7946 - val_accuracy: 0.0020 - val_top_k_categorical_accuracy: 0.0050
# Epoch 12/20
#  - 30s - loss: 1.3624 - accuracy: 0.5992 - top_k_categorical_accuracy: 0.9133 - val_loss: 7.8734 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 13/20
#  - 29s - loss: 1.3582 - accuracy: 0.5996 - top_k_categorical_accuracy: 0.9140 - val_loss: 8.1048 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 14/20
#  - 30s - loss: 1.3533 - accuracy: 0.6004 - top_k_categorical_accuracy: 0.9142 - val_loss: 7.9585 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 15/20
#  - 30s - loss: 1.3491 - accuracy: 0.6018 - top_k_categorical_accuracy: 0.9143 - val_loss: 8.0395 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 16/20
#  - 33s - loss: 1.3457 - accuracy: 0.6012 - top_k_categorical_accuracy: 0.9156 - val_loss: 7.7658 - val_accuracy: 0.0020 - val_top_k_categorical_accuracy: 0.0050
# Epoch 17/20
#  - 31s - loss: 1.3414 - accuracy: 0.6021 - top_k_categorical_accuracy: 0.9159 - val_loss: 7.9250 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0040
# Epoch 18/20
#  - 30s - loss: 1.3381 - accuracy: 0.6024 - top_k_categorical_accuracy: 0.9163 - val_loss: 8.2292 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 19/20
#  - 30s - loss: 1.3347 - accuracy: 0.6018 - top_k_categorical_accuracy: 0.9172 - val_loss: 8.1217 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
# Epoch 20/20
#  - 30s - loss: 1.3324 - accuracy: 0.6026 - top_k_categorical_accuracy: 0.9175 - val_loss: 8.0640 - val_accuracy: 0.0010 - val_top_k_categorical_accuracy: 0.0050
