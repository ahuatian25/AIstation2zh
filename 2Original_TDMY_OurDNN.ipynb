# %% [markdown]
# 实验八：引入了T_D_M_Y和OurDNN

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import keras

from keras import layers,metrics
from keras.optimizers import RMSprop
from keras.layers import Dense, LSTM, Dropout, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import PReLU, ELU
from keras.models import Sequential, load_model
from keras.utils import np_utils, multi_gpu_model

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder 
from sklearn.utils import shuffle as reset
from sklearn.model_selection import train_test_split,GridSearchCV,StratifiedShuffleSplit
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import log_loss,make_scorer

from matplotlib.colors import LogNorm
# import 
from matplotlib.pylab import plt
from copy import deepcopy
from datetime import datetime
from imblearn.over_sampling import RandomOverSampler #https://imbalanced-learn.org/stable/generated/imblearn.over_sampling.RandomOverSampler.html?highlight=randomoversampler
from frplayer import FilterResponseNormalization

# %%
def train_test_split_DataFrame(data, test_size=0.2, considerTime=True, random_state=None):
    # ConsiderTime-------trainDF和testDF分割时是否考虑时间问题，即是否需要随机打乱。True:按照‘Dates’列进行降序排列,False：随机打乱样本的顺序，
    if considerTime:
        data=data.sort_values(by="Dates", ascending=True)
    else:
        data=reset(data, random_state=random_state)
    train=data[int(len(data)*test_size):].reset_index(drop=True)
    test=data[:int(len(data)*test_size)].reset_index(drop=True)
    return train, test

# %%
def parse_time(x):
    DD=datetime.strptime(x,"%Y-%m-%d %H:%M")#zj    
    time=DD.hour#*60+DD.minute
    day=DD.day
    month=DD.month
    year=DD.year
    return time,day,month,year
def Dates2TDMY(x):
    DD=datetime.strptime(x,"%Y-%m-%d %H:%M")#zj  
    time=DD.hour#*60+DD.minute
    day=DD.day
    month=DD.month
    year=DD.year
    #T_D_M_Y=str(time)+str(day)+str(month)+str(year)
    T_D_M_Y=str(time)+str(day)+str(month)
    return T_D_M_Y
def get_season(x):
    summer=0
    fall=0
    winter=0
    spring=0
    if (x in [5, 6, 7]):
        summer=1
    if (x in [8, 9, 10]):
        fall=1
    if (x in [11, 0, 1]):
        winter=1
    if (x in [2, 3, 4]):
        spring=1
    return summer, fall, winter, spring

# %%
def field2Vec(trainDF,testDF,fieldStr):
    fields=sorted(trainDF[fieldStr].unique())
    categories=sorted(trainDF["Category"].unique())
    C_counts=trainDF.groupby(["Category"]).size()
    F_C_counts=trainDF.groupby([fieldStr,"Category"]).size()
    F_counts=trainDF.groupby([fieldStr]).size()
    logodds={}
    logoddsPF={}
    MIN_CAT_COUNTS=2
    default_logodds=np.log(C_counts/len(trainDF))-np.log(1.0-C_counts/float(len(trainDF)))
    for f in fields:
        PA=F_counts[f]/float(len(trainDF))
        logoddsPF[f]=np.log(PA)-np.log(1.-PA)
        logodds[f]=deepcopy(default_logodds)
        for cat in F_C_counts[f].keys():
            if (F_C_counts[f][cat]>MIN_CAT_COUNTS) and F_C_counts[f][cat]<F_counts[f]:
                PA=F_C_counts[f][cat]/float(F_counts[f])
                logodds[f][categories.index(cat)]=np.log(PA)-np.log(1.0-PA)
        logodds[f]=pd.Series(logodds[f])
        logodds[f].index=range(len(categories))
    ########此部分代码，从逻辑上不应该出现在此处，但是为了编程的方便，放在了此处#########
    #fieldsTest=sorted(testDF[fieldStr].unique())
    #N_count=0
    #for f in fieldsTest:
        #if f not in fields:
            #logoddsPF[f]=-50.0  #np.log(0.)-np.log(1.)=-inf,便于计算，改为-99999.0
            #logodds[f]=deepcopy(default_logodds)
            #pa=1.0/float(len(categories))
            #logodds[f][range(len(categories))]=np.log(pa)-np.log(1.0-pa)
            #logodds[f]=pd.Series(logodds[f])
            #logodds[f].index=range(len(categories))
            #N_count=N_count+1
    #print(fieldStr+' N_count: '+str(N_count))
    ########此部分代码，从逻辑上不应该出现在此处，但是为了编程的方便，放在了此处#########
    #引进代码原作者的新思想
    if testDF.shape[0]>0: #如果testDF里有样本,......
        print('There are some new:'+fieldStr)
        new_fields=sorted(testDF[fieldStr].unique())
        new_F_counts=testDF.groupby(fieldStr).size()
        only_new=set(new_fields+fields)-set(fields)
        only_old=set(new_fields+fields)-set(new_fields)
        in_both=set(new_fields).intersection(fields)
        print('# only_new_fieldds:'+str(len(only_new)))
        for f in only_new:
            PA=new_F_counts[f]/float(len(testDF)+len(trainDF))
            logoddsPF[f]=np.log(PA)-np.log(1.-PA)
            logodds[f]=deepcopy(default_logodds)
            logodds[f].index=range(len(categories))
        for f in in_both:
            PA=(F_counts[f]+new_F_counts[f])/float(len(testDF)+len(trainDF))
            logoddsPF[f]=np.log(PA)-np.log(1.-PA)    
    return logodds,logoddsPF

# %%
def parse_data(df,logodds_A,logoddsPF_A,logodds_T,logoddsPF_T,needT_D_M_Y=False):
    feature_list=df.columns.tolist()
    if "Descript" in feature_list:
        feature_list.remove("Descript")
    if "Resolution" in feature_list:
        feature_list.remove("Resolution")
    if "Category" in feature_list:
        feature_list.remove("Category")
    if "Id" in feature_list:
        feature_list.remove("Id")

    cleanData=df[feature_list]
    cleanData.index=range(len(df))
    print("Creating address features")###Creating address features###
    address_features=cleanData["Address"].apply(lambda x: logodds_A[x])
    address_features.columns=["logodds_A"+str(x) for x in range(len(address_features.columns))]
    if needT_D_M_Y:
        print("Creating time T_D_M_Y features")###Creating time T_D_M_Y features###
        T_D_M_Y_features=cleanData["T_D_M_Y"].apply(lambda xx: logodds_T[xx])
        T_D_M_Y_features.columns=["logodds_T"+str(xx) for xx in range(len(T_D_M_Y_features.columns))]

    print("Parsing dates")            ###Creating address features###
    cleanData["Time"], cleanData["Day"], cleanData["Month"], cleanData["Year"]=zip(*cleanData["Dates"].apply(parse_time))
    #     dummy_ranks_DAY = pd.get_dummies(cleanData['DayOfWeek'], prefix='DAY')
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    #     cleanData["DayOfWeek"]=cleanData["DayOfWeek"].apply(lambda x: days.index(x)/float(len(days)))
    print("Creating one-hot variables")
    dummy_ranks_PD = pd.get_dummies(cleanData['PdDistrict'], prefix='PD')
    dummy_ranks_DAY = pd.get_dummies(cleanData["DayOfWeek"], prefix='DAY')
    cleanData["IsInterection"]=cleanData["Address"].apply(lambda x: 1 if "/" in x else 0)
    cleanData["logoddsPF_A"]=cleanData["Address"].apply(lambda x: logoddsPF_A[x])
    if needT_D_M_Y:
        cleanData["logoddsPF_T"]=cleanData["T_D_M_Y"].apply(lambda x: logoddsPF_T[x])
    print("droping processed columns")
    cleanData=cleanData.drop("PdDistrict",axis=1)
    cleanData=cleanData.drop("DayOfWeek",axis=1)
    cleanData=cleanData.drop("Address",axis=1)    
    cleanData=cleanData.drop("Dates",axis=1)
    if needT_D_M_Y:
        cleanData=cleanData.drop("T_D_M_Y",axis=1)
    feature_list=cleanData.columns.tolist()
    print("joining one-hot features")
    if needT_D_M_Y:
        features = cleanData[feature_list].join(dummy_ranks_PD.iloc[:,:]).join(dummy_ranks_DAY.iloc[:,:]).join(address_features.iloc[:,:]).join(T_D_M_Y_features.iloc[:,:])
    else:
        features = cleanData[feature_list].join(dummy_ranks_PD.iloc[:,:]).join(dummy_ranks_DAY.iloc[:,:]).join(address_features.iloc[:,:])
    print("creating new features")
    features["IsDup"]=pd.Series(features.duplicated()|features.duplicated(keep='last')).apply(int)
    features["Awake"]=features["Time"].apply(lambda x: 1 if (x==0 or (x>=8 and x<=23)) else 0)
    features["Summer"], features["Fall"], features["Winter"], features["Spring"]=zip(*features["Month"].apply(get_season))
    if "Category" in df.columns:
        labels = df["Category"].astype('category')
    else:
        labels=None
    return features,labels

# %%
def generator(X, Y, lookback, delay, min_index, max_index, shuffle=False, batch_size=128, step=6):
    if max_index is None:
        max_index = len(X) - delay - 1
    i = min_index + lookback
    while 1:
        if shuffle:
            rows = np.random.randint(min_index + lookback, max_index, size=batch_size)
        else:
            if i + batch_size >= max_index:
                i = min_index + lookback
            rows = np.arange(i, min(i + batch_size, max_index))
            i += len(rows)

        samples = np.zeros((len(rows), lookback // step, X.shape[-1]))
        targets = np.zeros((len(rows),Y.shape[1]))
        for j, row in enumerate(rows):
            indices = range(rows[j] - lookback, rows[j], step)
            samples[j] = X[indices]
            targets[j] = Y[rows[j]+delay]
        yield samples, targets
    #Now here is the data generator that we will use. It yields a tuple (samples, targets) where samples is one batch of input data and targets is the corresponding array of target temperatures. It takes the following arguments:
        # •data: The original array of floating point data, which we just normalized in the code snippet above.
        # •lookback: How many timesteps back should our input data go.
        # •delay: How many timesteps in the future should our target be.
        # •min_index and max_index: Indices in the data array that delimit which timesteps to draw from. This is useful for keeping a segment of the data for validation and another one for testing.
        # •shuffle: Whether to shuffle our samples or draw them in chronological order.
        # •batch_size: The number of samples per batch.
        # •step: The period, in timesteps, at which we sample data. We will set it 6 in order to draw one data point every hour.

# %%
#Import data
ConsiderTime=False# True##trainDF和testDF分割时是否考虑时间问题，即是否需要随机打乱。True:按照‘Dates’列进行降序排列,False：随机打乱样本的顺序，
Rate_ALL=0.0 #0.0即不保留测试机
needOverSampler=False
needT_D_M_Y=True #False  使用_T_D_M_Y和周几
allDF=pd.read_csv("./train_addrCorrect.csv")
print('The shape of OrginalAllDF: '+str(allDF.shape))

xy_scaler=preprocessing.StandardScaler()
xy_scaler.fit(allDF[["X","Y"]])
allDF[["X","Y"]]=xy_scaler.transform(allDF[["X","Y"]])
allDF=allDF[abs(allDF["Y"])<100]
allDF.index=range(len(allDF))
print('The shape of AllDF after del wrong X and Y values: '+str(allDF.shape))

def listCat(x):
    return list(x)
allDF.drop_duplicates(inplace=True,subset=['Dates', 'DayOfWeek', 'PdDistrict', 'Address', 'X', 'Y', 'Category'])
Train_duplicated=pd.pivot_table(allDF,index=['Dates','DayOfWeek','PdDistrict', 'Address', 'X', 'Y'], values='Category',aggfunc=[len,listCat])
print('The shape of AllDF after drop_duplicates: '+str(allDF.shape))
print(Train_duplicated.shape)

cate_group = allDF.groupby(by='Category').size()
cate_group

trainDF,testDF=train_test_split_DataFrame(allDF, test_size=Rate_ALL, considerTime=ConsiderTime, random_state=None)
print('Address_counts_allDF_trainDF_testDF: ' + str(len(allDF["Address"].unique())) + '_'+ str(len(trainDF["Address"].unique())) + '_' + str(len(testDF["Address"].unique())))

N_AllSample=allDF.shape[0]
N_AllTrain=trainDF.shape[0]
N_AllTest=testDF.shape[0]
N_CLASS=len(allDF["Category"].unique())
print('The # of AllDF, AllTrain, AllTest, is: '+str(N_AllSample)+','+str(N_AllTrain)+','+str(N_AllTest))
#################Now proceed as before#################
print('-----------LOGOODS: Address-------------')
logodds_A,logoddsPF_A=field2Vec(trainDF,testDF,"Address")
if needT_D_M_Y:
    trainDF["T_D_M_Y"]=trainDF["Dates"].apply(Dates2TDMY)
    trainDF["T_D_M_Y"]=trainDF["T_D_M_Y"]+trainDF["DayOfWeek"]
    if Rate_ALL>0:
        testDF[["X","Y"]]=xy_scaler.transform(testDF[["X","Y"]])
        testDF["T_D_M_Y"]=testDF["Dates"].apply(Dates2TDMY)
        testDF["T_D_M_Y"]=testDF["T_D_M_Y"]+testDF["DayOfWeek"]
    print('-----------LOGOODS: T_D_M_Y-------------')
    logodds_T,logoddsPF_T=field2Vec(trainDF,testDF,"T_D_M_Y")    
else:
    logodds_T=None
    logoddsPF_T=None
    
print('-----------LOGOODS: parse_data of Alltrain  -------------')
features, labels=parse_data(trainDF,logodds_A,logoddsPF_A,logodds_T,logoddsPF_T,needT_D_M_Y) 
if Rate_ALL>0:
    print('-----------LOGOODS: parse_data of Alltest  -------------')
    features_test, labels_test=parse_data(testDF,logodds_A,logoddsPF_A,logodds_T,logoddsPF_T,needT_D_M_Y)###########和训练集使用同样的时间和地点Logoodds值#####
    x_test=features_test.values
    y_test=labels_test.values
    y_test = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_test)), num_classes=N_CLASS)

print(features.columns.tolist())
print(len(features.columns))

collist=features.columns.tolist()
scaler = preprocessing.StandardScaler()
scaler.fit(features)
features[collist]=scaler.transform(features)
if Rate_ALL>0:
    features_test[collist]=scaler.transform(features_test)###########和训练集使用同样的scaler值#####
######################################################
#############################先进行过采样，然后再根据时间来排序##################################
if needOverSampler:
    print('------------RandomOverSampler--------------')
    ros = RandomOverSampler()
    featuresArrayOverSampler, labelsArrayOverSampler = ros.fit_resample(features.values,labels.values)#####过采样#####
    N_AllTrain_OverSampler=int(featuresArrayOverSampler.shape[0])
    print('Shape of OverSampler of AllTrain: '+str(featuresArrayOverSampler.shape))
else:
    featuresArrayOverSampler=features.values
    labelsArrayOverSampler=labels.values
    N_AllTrain_OverSampler=int(featuresArrayOverSampler.shape[0])
    print('------------Attention: we do not RandomOverSampler---------------')
if ConsiderTime:
    #####按照年（第6列）月（第5列）日（第4列）时（第3列）排序
    print('------------Sort--------------')
    time_temp=featuresArrayOverSampler[:,2]+np.dot(featuresArrayOverSampler[:,3],100)+np.dot(featuresArrayOverSampler[:,4],10000)+np.dot(featuresArrayOverSampler[:,5],1000000)
    features_label_time=np.column_stack((featuresArrayOverSampler,labelsArrayOverSampler))
    features_label_time=np.column_stack((features_label_time,time_temp))
    features_label_time =features_label_time[np.argsort(features_label_time[:,-1])]
    labelsArrayOverSampler=features_label_time[:,-2]
    featuresArrayOverSampler=features_label_time[:,0:featuresArrayOverSampler.shape[1]]
    del features_label_time
    #############################先进行过采样，然后再根据时间来排序----结束############################
if Rate_ALL>0:
    print('------------RandomOverSampler for AllTest--------------')
    ros = RandomOverSampler()
    featuresArray_test, labelsArray_test = ros.fit_resample(features_test.values,labels_test.values)#####过采样#####
    N_AllTest_OverSampler=int(featuresArray_test.shape[0])
    labelsArray_test = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(labelsArray_test)), num_classes=N_CLASS)
    print('Shape of OverSampler of AllTest: '+str(featuresArray_test.shape))
# Out:
# The shape of OrginalAllDF: (145962, 9)
# The shape of AllDF after del wrong X and Y values: (145960, 9)
# The shape of AllDF after drop_duplicates: (145876, 9)
# (145859, 2)
# Address_counts_allDF_trainDF_testDF: 17161_17161_0
# The # of AllDF, AllTrain, AllTest, is: 145876,145876,0
# -----------LOGOODS: Address-------------
# -----------LOGOODS: T_D_M_Y-------------
# -----------LOGOODS: parse_data of Alltrain  -------------
# Creating address features
# Creating time T_D_M_Y features
# Parsing dates
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Creating one-hot variables
# droping processed columns
# joining one-hot features
# creating new features
# ['X', 'Y', 'Time', 'Day', 'Month', 'Year', 'IsInterection', 'logoddsPF_A', 'logoddsPF_T', 'PD_星期一', 'PD_星期三', 'PD_星期二', 'PD_星期五', 'PD_星期六', 'PD_星期四', 'PD_星期日', 'DAY_星期一', 'DAY_星期三', 'DAY_星期二', 'DAY_星期五', 'DAY_星期六', 'DAY_星期四', 'DAY_星期日', 'logodds_A0', 'logodds_A1', 'logodds_A2', 'logodds_A3', 'logodds_A4', 'logodds_A5', 'logodds_A6', 'logodds_A7', 'logodds_A8', 'logodds_A9', 'logodds_A10', 'logodds_A11', 'logodds_A12', 'logodds_A13', 'logodds_A14', 'logodds_A15', 'logodds_A16', 'logodds_A17', 'logodds_A18', 'logodds_A19', 'logodds_A20', 'logodds_A21', 'logodds_A22', 'logodds_A23', 'logodds_A24', 'logodds_A25', 'logodds_A26', 'logodds_A27', 'logodds_A28', 'logodds_A29', 'logodds_A30', 'logodds_A31', 'logodds_A32', 'logodds_A33', 'logodds_A34', 'logodds_A35', 'logodds_A36', 'logodds_A37', 'logodds_A38', 'logodds_A39', 'logodds_A40', 'logodds_A41', 'logodds_A42', 'logodds_A43', 'logodds_A44', 'logodds_A45', 'logodds_A46', 'logodds_A47', 'logodds_A48', 'logodds_A49', 'logodds_T0', 'logodds_T1', 'logodds_T2', 'logodds_T3', 'logodds_T4', 'logodds_T5', 'logodds_T6', 'logodds_T7', 'logodds_T8', 'logodds_T9', 'logodds_T10', 'logodds_T11', 'logodds_T12', 'logodds_T13', 'logodds_T14', 'logodds_T15', 'logodds_T16', 'logodds_T17', 'logodds_T18', 'logodds_T19', 'logodds_T20', 'logodds_T21', 'logodds_T22', 'logodds_T23', 'logodds_T24', 'logodds_T25', 'logodds_T26', 'logodds_T27', 'logodds_T28', 'logodds_T29', 'logodds_T30', 'logodds_T31', 'logodds_T32', 'logodds_T33', 'logodds_T34', 'logodds_T35', 'logodds_T36', 'logodds_T37', 'logodds_T38', 'logodds_T39', 'logodds_T40', 'logodds_T41', 'logodds_T42', 'logodds_T43', 'logodds_T44', 'logodds_T45', 'logodds_T46', 'logodds_T47', 'logodds_T48', 'logodds_T49', 'IsDup', 'Awake', 'Summer', 'Fall', 'Winter', 'Spring']
# 129
# ------------Attention: we do not RandomOverSampler---------------

# %% [markdown]
# 实验九：实验八：D128-D64

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=60
N_HN_1=128
N_HN=64
N_LAYERS=1
N_BATCH=16
dp=0.5
Rate_Val=0.5
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])

x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)
# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####

y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
model.save('jjs_model_0124V3.h5')

loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS9.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC9.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC9.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 72938 samples, validate on 72938 samples
# Epoch 1/60
#  - 66s - loss: 1.6176 - accuracy: 0.5641 - top_k_categorical_accuracy: 0.8728 - val_loss: 1.4736 - val_accuracy: 0.5840 - val_top_k_categorical_accuracy: 0.8991
# Epoch 2/60
#  - 65s - loss: 1.4683 - accuracy: 0.5821 - top_k_categorical_accuracy: 0.9002 - val_loss: 1.4500 - val_accuracy: 0.5879 - val_top_k_categorical_accuracy: 0.9015
# Epoch 3/60
#  - 68s - loss: 1.4509 - accuracy: 0.5857 - top_k_categorical_accuracy: 0.9017 - val_loss: 1.4411 - val_accuracy: 0.5922 - val_top_k_categorical_accuracy: 0.9033
# Epoch 4/60
#  - 67s - loss: 1.4409 - accuracy: 0.5859 - top_k_categorical_accuracy: 0.9037 - val_loss: 1.4362 - val_accuracy: 0.5918 - val_top_k_categorical_accuracy: 0.9033
# Epoch 5/60
#  - 67s - loss: 1.4314 - accuracy: 0.5876 - top_k_categorical_accuracy: 0.9045 - val_loss: 1.4318 - val_accuracy: 0.5935 - val_top_k_categorical_accuracy: 0.9040
# Epoch 6/60
#  - 66s - loss: 1.4276 - accuracy: 0.5869 - top_k_categorical_accuracy: 0.9049 - val_loss: 1.4351 - val_accuracy: 0.5923 - val_top_k_categorical_accuracy: 0.9028
# Epoch 7/60
#  - 65s - loss: 1.4231 - accuracy: 0.5897 - top_k_categorical_accuracy: 0.9053 - val_loss: 1.4292 - val_accuracy: 0.5927 - val_top_k_categorical_accuracy: 0.9033
# Epoch 8/60
#  - 64s - loss: 1.4163 - accuracy: 0.5892 - top_k_categorical_accuracy: 0.9056 - val_loss: 1.4286 - val_accuracy: 0.5926 - val_top_k_categorical_accuracy: 0.9044
# Epoch 9/60
#  - 66s - loss: 1.4117 - accuracy: 0.5891 - top_k_categorical_accuracy: 0.9068 - val_loss: 1.4276 - val_accuracy: 0.5936 - val_top_k_categorical_accuracy: 0.9035
# Epoch 10/60
#  - 66s - loss: 1.4092 - accuracy: 0.5907 - top_k_categorical_accuracy: 0.9074 - val_loss: 1.4288 - val_accuracy: 0.5944 - val_top_k_categorical_accuracy: 0.9039
# Epoch 11/60
#  - 65s - loss: 1.4067 - accuracy: 0.5912 - top_k_categorical_accuracy: 0.9072 - val_loss: 1.4283 - val_accuracy: 0.5946 - val_top_k_categorical_accuracy: 0.9043
# Epoch 12/60
#  - 64s - loss: 1.4023 - accuracy: 0.5918 - top_k_categorical_accuracy: 0.9082 - val_loss: 1.4305 - val_accuracy: 0.5943 - val_top_k_categorical_accuracy: 0.9040
# Epoch 13/60
#  - 63s - loss: 1.3987 - accuracy: 0.5922 - top_k_categorical_accuracy: 0.9088 - val_loss: 1.4331 - val_accuracy: 0.5932 - val_top_k_categorical_accuracy: 0.9036
# Epoch 14/60
#  - 64s - loss: 1.3941 - accuracy: 0.5929 - top_k_categorical_accuracy: 0.9099 - val_loss: 1.4324 - val_accuracy: 0.5942 - val_top_k_categorical_accuracy: 0.9031
# Epoch 15/60
#  - 66s - loss: 1.3946 - accuracy: 0.5937 - top_k_categorical_accuracy: 0.9100 - val_loss: 1.4361 - val_accuracy: 0.5929 - val_top_k_categorical_accuracy: 0.9035
# Epoch 16/60
#  - 66s - loss: 1.3897 - accuracy: 0.5942 - top_k_categorical_accuracy: 0.9097 - val_loss: 1.4336 - val_accuracy: 0.5935 - val_top_k_categorical_accuracy: 0.9028
# Epoch 17/60
#  - 63s - loss: 1.3895 - accuracy: 0.5940 - top_k_categorical_accuracy: 0.9092 - val_loss: 1.4348 - val_accuracy: 0.5940 - val_top_k_categorical_accuracy: 0.9041
# Epoch 18/60
#  - 65s - loss: 1.3856 - accuracy: 0.5939 - top_k_categorical_accuracy: 0.9108 - val_loss: 1.4366 - val_accuracy: 0.5924 - val_top_k_categorical_accuracy: 0.9039
# Epoch 19/60
#  - 66s - loss: 1.3815 - accuracy: 0.5940 - top_k_categorical_accuracy: 0.9106 - val_loss: 1.4389 - val_accuracy: 0.5924 - val_top_k_categorical_accuracy: 0.9036
# Epoch 20/60
#  - 65s - loss: 1.3815 - accuracy: 0.5945 - top_k_categorical_accuracy: 0.9114 - val_loss: 1.4420 - val_accuracy: 0.5922 - val_top_k_categorical_accuracy: 0.9041
# Epoch 21/60
#  - 64s - loss: 1.3776 - accuracy: 0.5953 - top_k_categorical_accuracy: 0.9115 - val_loss: 1.4424 - val_accuracy: 0.5931 - val_top_k_categorical_accuracy: 0.9030
# Epoch 22/60
#  - 66s - loss: 1.3758 - accuracy: 0.5966 - top_k_categorical_accuracy: 0.9111 - val_loss: 1.4414 - val_accuracy: 0.5942 - val_top_k_categorical_accuracy: 0.9028
# Epoch 23/60
#  - 64s - loss: 1.3746 - accuracy: 0.5950 - top_k_categorical_accuracy: 0.9130 - val_loss: 1.4467 - val_accuracy: 0.5918 - val_top_k_categorical_accuracy: 0.9033
# Epoch 24/60
#  - 64s - loss: 1.3738 - accuracy: 0.5969 - top_k_categorical_accuracy: 0.9125 - val_loss: 1.4408 - val_accuracy: 0.5932 - val_top_k_categorical_accuracy: 0.9036
# Epoch 25/60
#  - 69s - loss: 1.3698 - accuracy: 0.5970 - top_k_categorical_accuracy: 0.9128 - val_loss: 1.4463 - val_accuracy: 0.5928 - val_top_k_categorical_accuracy: 0.9026
# Epoch 26/60
#  - 64s - loss: 1.3701 - accuracy: 0.5971 - top_k_categorical_accuracy: 0.9126 - val_loss: 1.4435 - val_accuracy: 0.5919 - val_top_k_categorical_accuracy: 0.9037
# Epoch 27/60
#  - 63s - loss: 1.3678 - accuracy: 0.5974 - top_k_categorical_accuracy: 0.9129 - val_loss: 1.4443 - val_accuracy: 0.5938 - val_top_k_categorical_accuracy: 0.9036
# Epoch 28/60
#  - 67s - loss: 1.3670 - accuracy: 0.5966 - top_k_categorical_accuracy: 0.9136 - val_loss: 1.4474 - val_accuracy: 0.5921 - val_top_k_categorical_accuracy: 0.9019
# Epoch 29/60
#  - 64s - loss: 1.3663 - accuracy: 0.5970 - top_k_categorical_accuracy: 0.9128 - val_loss: 1.4434 - val_accuracy: 0.5929 - val_top_k_categorical_accuracy: 0.9028
# Epoch 30/60
#  - 66s - loss: 1.3632 - accuracy: 0.5976 - top_k_categorical_accuracy: 0.9145 - val_loss: 1.4431 - val_accuracy: 0.5934 - val_top_k_categorical_accuracy: 0.9029
# Epoch 31/60
#  - 63s - loss: 1.3638 - accuracy: 0.5979 - top_k_categorical_accuracy: 0.9126 - val_loss: 1.4478 - val_accuracy: 0.5904 - val_top_k_categorical_accuracy: 0.9027
# Epoch 32/60
#  - 65s - loss: 1.3614 - accuracy: 0.5971 - top_k_categorical_accuracy: 0.9140 - val_loss: 1.4506 - val_accuracy: 0.5912 - val_top_k_categorical_accuracy: 0.9024
# Epoch 33/60
#  - 67s - loss: 1.3599 - accuracy: 0.5976 - top_k_categorical_accuracy: 0.9140 - val_loss: 1.4486 - val_accuracy: 0.5927 - val_top_k_categorical_accuracy: 0.9030
# Epoch 34/60
#  - 63s - loss: 1.3607 - accuracy: 0.5977 - top_k_categorical_accuracy: 0.9143 - val_loss: 1.4476 - val_accuracy: 0.5911 - val_top_k_categorical_accuracy: 0.9026
# Epoch 35/60
#  - 65s - loss: 1.3552 - accuracy: 0.5981 - top_k_categorical_accuracy: 0.9160 - val_loss: 1.4485 - val_accuracy: 0.5905 - val_top_k_categorical_accuracy: 0.9029
# Epoch 36/60
#  - 67s - loss: 1.3567 - accuracy: 0.5983 - top_k_categorical_accuracy: 0.9145 - val_loss: 1.4486 - val_accuracy: 0.5921 - val_top_k_categorical_accuracy: 0.9028
# Epoch 37/60
#  - 65s - loss: 1.3550 - accuracy: 0.5978 - top_k_categorical_accuracy: 0.9158 - val_loss: 1.4491 - val_accuracy: 0.5913 - val_top_k_categorical_accuracy: 0.9024
# Epoch 38/60
#  - 66s - loss: 1.3535 - accuracy: 0.5985 - top_k_categorical_accuracy: 0.9149 - val_loss: 1.4556 - val_accuracy: 0.5902 - val_top_k_categorical_accuracy: 0.9013
# Epoch 39/60
#  - 66s - loss: 1.3544 - accuracy: 0.5980 - top_k_categorical_accuracy: 0.9154 - val_loss: 1.4577 - val_accuracy: 0.5906 - val_top_k_categorical_accuracy: 0.9014
# Epoch 40/60
#  - 66s - loss: 1.3531 - accuracy: 0.5987 - top_k_categorical_accuracy: 0.9145 - val_loss: 1.4529 - val_accuracy: 0.5918 - val_top_k_categorical_accuracy: 0.9017
# Epoch 41/60
#  - 66s - loss: 1.3528 - accuracy: 0.5997 - top_k_categorical_accuracy: 0.9151 - val_loss: 1.4521 - val_accuracy: 0.5916 - val_top_k_categorical_accuracy: 0.9020
# Epoch 42/60
#  - 65s - loss: 1.3531 - accuracy: 0.5988 - top_k_categorical_accuracy: 0.9154 - val_loss: 1.4548 - val_accuracy: 0.5922 - val_top_k_categorical_accuracy: 0.9022
# Epoch 43/60
#  - 64s - loss: 1.3502 - accuracy: 0.5990 - top_k_categorical_accuracy: 0.9158 - val_loss: 1.4591 - val_accuracy: 0.5924 - val_top_k_categorical_accuracy: 0.9016
# Epoch 44/60
#  - 64s - loss: 1.3471 - accuracy: 0.6000 - top_k_categorical_accuracy: 0.9162 - val_loss: 1.4557 - val_accuracy: 0.5923 - val_top_k_categorical_accuracy: 0.9019
# Epoch 45/60
#  - 65s - loss: 1.3472 - accuracy: 0.6002 - top_k_categorical_accuracy: 0.9155 - val_loss: 1.4582 - val_accuracy: 0.5918 - val_top_k_categorical_accuracy: 0.9017
# Epoch 46/60
#  - 66s - loss: 1.3468 - accuracy: 0.6000 - top_k_categorical_accuracy: 0.9160 - val_loss: 1.4576 - val_accuracy: 0.5912 - val_top_k_categorical_accuracy: 0.9008
# Epoch 47/60
#  - 66s - loss: 1.3455 - accuracy: 0.6000 - top_k_categorical_accuracy: 0.9159 - val_loss: 1.4606 - val_accuracy: 0.5904 - val_top_k_categorical_accuracy: 0.9021
# Epoch 48/60
#  - 66s - loss: 1.3431 - accuracy: 0.5997 - top_k_categorical_accuracy: 0.9165 - val_loss: 1.4630 - val_accuracy: 0.5922 - val_top_k_categorical_accuracy: 0.9020
# Epoch 49/60
#  - 67s - loss: 1.3455 - accuracy: 0.6001 - top_k_categorical_accuracy: 0.9165 - val_loss: 1.4613 - val_accuracy: 0.5930 - val_top_k_categorical_accuracy: 0.9014
# Epoch 50/60
#  - 67s - loss: 1.3420 - accuracy: 0.5997 - top_k_categorical_accuracy: 0.9167 - val_loss: 1.4610 - val_accuracy: 0.5902 - val_top_k_categorical_accuracy: 0.9007
# Epoch 51/60
#  - 69s - loss: 1.3420 - accuracy: 0.6005 - top_k_categorical_accuracy: 0.9171 - val_loss: 1.4583 - val_accuracy: 0.5910 - val_top_k_categorical_accuracy: 0.9013
# Epoch 52/60
#  - 67s - loss: 1.3413 - accuracy: 0.6008 - top_k_categorical_accuracy: 0.9173 - val_loss: 1.4610 - val_accuracy: 0.5911 - val_top_k_categorical_accuracy: 0.9021
# Epoch 53/60
#  - 65s - loss: 1.3421 - accuracy: 0.6000 - top_k_categorical_accuracy: 0.9171 - val_loss: 1.4596 - val_accuracy: 0.5904 - val_top_k_categorical_accuracy: 0.9003
# Epoch 54/60
#  - 62s - loss: 1.3401 - accuracy: 0.5994 - top_k_categorical_accuracy: 0.9172 - val_loss: 1.4570 - val_accuracy: 0.5918 - val_top_k_categorical_accuracy: 0.9008
# Epoch 55/60
#  - 65s - loss: 1.3376 - accuracy: 0.6004 - top_k_categorical_accuracy: 0.9177 - val_loss: 1.4637 - val_accuracy: 0.5903 - val_top_k_categorical_accuracy: 0.9018
# Epoch 56/60
#  - 64s - loss: 1.3386 - accuracy: 0.6009 - top_k_categorical_accuracy: 0.9172 - val_loss: 1.4652 - val_accuracy: 0.5901 - val_top_k_categorical_accuracy: 0.9014
# Epoch 57/60
#  - 63s - loss: 1.3402 - accuracy: 0.6004 - top_k_categorical_accuracy: 0.9177 - val_loss: 1.4597 - val_accuracy: 0.5917 - val_top_k_categorical_accuracy: 0.9020
# Epoch 58/60
#  - 64s - loss: 1.3359 - accuracy: 0.6021 - top_k_categorical_accuracy: 0.9176 - val_loss: 1.4585 - val_accuracy: 0.5919 - val_top_k_categorical_accuracy: 0.9023
# Epoch 59/60
#  - 66s - loss: 1.3354 - accuracy: 0.5995 - top_k_categorical_accuracy: 0.9187 - val_loss: 1.4624 - val_accuracy: 0.5898 - val_top_k_categorical_accuracy: 0.9012
# Epoch 60/60
#  - 64s - loss: 1.3354 - accuracy: 0.6018 - top_k_categorical_accuracy: 0.9175 - val_loss: 1.4639 - val_accuracy: 0.5916 - val_top_k_categorical_accuracy: 0.9012

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=60
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=16
dp=0.5
Rate_Val=0.5
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])

x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)
# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####

y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
# model.save('jjs_model_0124V3.h5')

loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS9.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC9.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC9.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 72938 samples, validate on 72938 samples
# Epoch 1/60
#  - 64s - loss: 1.6111 - accuracy: 0.5648 - top_k_categorical_accuracy: 0.8769 - val_loss: 1.4874 - val_accuracy: 0.5818 - val_top_k_categorical_accuracy: 0.8991
# Epoch 2/60
#  - 62s - loss: 1.4672 - accuracy: 0.5819 - top_k_categorical_accuracy: 0.9005 - val_loss: 1.4622 - val_accuracy: 0.5863 - val_top_k_categorical_accuracy: 0.9014
# Epoch 3/60
#  - 63s - loss: 1.4495 - accuracy: 0.5853 - top_k_categorical_accuracy: 0.9028 - val_loss: 1.4448 - val_accuracy: 0.5907 - val_top_k_categorical_accuracy: 0.9015
# Epoch 4/60
#  - 64s - loss: 1.4358 - accuracy: 0.5876 - top_k_categorical_accuracy: 0.9028 - val_loss: 1.4457 - val_accuracy: 0.5888 - val_top_k_categorical_accuracy: 0.9027
# Epoch 5/60
#  - 62s - loss: 1.4284 - accuracy: 0.5882 - top_k_categorical_accuracy: 0.9058 - val_loss: 1.4425 - val_accuracy: 0.5909 - val_top_k_categorical_accuracy: 0.9021
# Epoch 6/60
#  - 62s - loss: 1.4191 - accuracy: 0.5906 - top_k_categorical_accuracy: 0.9065 - val_loss: 1.4416 - val_accuracy: 0.5898 - val_top_k_categorical_accuracy: 0.9038
# Epoch 7/60
#  - 64s - loss: 1.4112 - accuracy: 0.5913 - top_k_categorical_accuracy: 0.9069 - val_loss: 1.4387 - val_accuracy: 0.5921 - val_top_k_categorical_accuracy: 0.9032
# Epoch 8/60
#  - 61s - loss: 1.4088 - accuracy: 0.5904 - top_k_categorical_accuracy: 0.9083 - val_loss: 1.4415 - val_accuracy: 0.5907 - val_top_k_categorical_accuracy: 0.9024
# Epoch 9/60
#  - 63s - loss: 1.4021 - accuracy: 0.5923 - top_k_categorical_accuracy: 0.9090 - val_loss: 1.4399 - val_accuracy: 0.5923 - val_top_k_categorical_accuracy: 0.9035
# Epoch 10/60
#  - 62s - loss: 1.3964 - accuracy: 0.5930 - top_k_categorical_accuracy: 0.9086 - val_loss: 1.4422 - val_accuracy: 0.5917 - val_top_k_categorical_accuracy: 0.9026
# Epoch 11/60
#  - 65s - loss: 1.3904 - accuracy: 0.5948 - top_k_categorical_accuracy: 0.9102 - val_loss: 1.4426 - val_accuracy: 0.5918 - val_top_k_categorical_accuracy: 0.9030
# Epoch 12/60
#  - 63s - loss: 1.3858 - accuracy: 0.5944 - top_k_categorical_accuracy: 0.9104 - val_loss: 1.4485 - val_accuracy: 0.5917 - val_top_k_categorical_accuracy: 0.9035
# Epoch 13/60
#  - 65s - loss: 1.3825 - accuracy: 0.5948 - top_k_categorical_accuracy: 0.9118 - val_loss: 1.4499 - val_accuracy: 0.5918 - val_top_k_categorical_accuracy: 0.9014
# Epoch 14/60
#  - 62s - loss: 1.3769 - accuracy: 0.5950 - top_k_categorical_accuracy: 0.9115 - val_loss: 1.4517 - val_accuracy: 0.5917 - val_top_k_categorical_accuracy: 0.9014
# Epoch 15/60
#  - 63s - loss: 1.3717 - accuracy: 0.5947 - top_k_categorical_accuracy: 0.9129 - val_loss: 1.4561 - val_accuracy: 0.5923 - val_top_k_categorical_accuracy: 0.9025
# Epoch 16/60
#  - 64s - loss: 1.3707 - accuracy: 0.5965 - top_k_categorical_accuracy: 0.9122 - val_loss: 1.4557 - val_accuracy: 0.5901 - val_top_k_categorical_accuracy: 0.9011
# Epoch 17/60
#  - 62s - loss: 1.3672 - accuracy: 0.5949 - top_k_categorical_accuracy: 0.9129 - val_loss: 1.4542 - val_accuracy: 0.5897 - val_top_k_categorical_accuracy: 0.9011
# Epoch 18/60
#  - 62s - loss: 1.3603 - accuracy: 0.5981 - top_k_categorical_accuracy: 0.9126 - val_loss: 1.4540 - val_accuracy: 0.5890 - val_top_k_categorical_accuracy: 0.9022
# Epoch 19/60
#  - 63s - loss: 1.3590 - accuracy: 0.5967 - top_k_categorical_accuracy: 0.9152 - val_loss: 1.4589 - val_accuracy: 0.5906 - val_top_k_categorical_accuracy: 0.9014
# Epoch 20/60
#  - 63s - loss: 1.3555 - accuracy: 0.5969 - top_k_categorical_accuracy: 0.9154 - val_loss: 1.4558 - val_accuracy: 0.5916 - val_top_k_categorical_accuracy: 0.9018
# Epoch 21/60
#  - 63s - loss: 1.3534 - accuracy: 0.5981 - top_k_categorical_accuracy: 0.9153 - val_loss: 1.4650 - val_accuracy: 0.5893 - val_top_k_categorical_accuracy: 0.9008
# Epoch 22/60
#  - 67s - loss: 1.3517 - accuracy: 0.5979 - top_k_categorical_accuracy: 0.9165 - val_loss: 1.4723 - val_accuracy: 0.5891 - val_top_k_categorical_accuracy: 0.9001
# Epoch 23/60
#  - 65s - loss: 1.3469 - accuracy: 0.5989 - top_k_categorical_accuracy: 0.9163 - val_loss: 1.4686 - val_accuracy: 0.5891 - val_top_k_categorical_accuracy: 0.9016
# Epoch 24/60
#  - 64s - loss: 1.3465 - accuracy: 0.5982 - top_k_categorical_accuracy: 0.9156 - val_loss: 1.4651 - val_accuracy: 0.5896 - val_top_k_categorical_accuracy: 0.9006
# Epoch 25/60
#  - 67s - loss: 1.3431 - accuracy: 0.5987 - top_k_categorical_accuracy: 0.9166 - val_loss: 1.4666 - val_accuracy: 0.5899 - val_top_k_categorical_accuracy: 0.9009
# Epoch 26/60
#  - 63s - loss: 1.3435 - accuracy: 0.5995 - top_k_categorical_accuracy: 0.9172 - val_loss: 1.4668 - val_accuracy: 0.5915 - val_top_k_categorical_accuracy: 0.9014
# Epoch 27/60
#  - 63s - loss: 1.3407 - accuracy: 0.5995 - top_k_categorical_accuracy: 0.9176 - val_loss: 1.4769 - val_accuracy: 0.5895 - val_top_k_categorical_accuracy: 0.8996
# Epoch 28/60
#  - 63s - loss: 1.3352 - accuracy: 0.5995 - top_k_categorical_accuracy: 0.9170 - val_loss: 1.4794 - val_accuracy: 0.5888 - val_top_k_categorical_accuracy: 0.8992
# Epoch 29/60
#  - 62s - loss: 1.3347 - accuracy: 0.6007 - top_k_categorical_accuracy: 0.9179 - val_loss: 1.4769 - val_accuracy: 0.5900 - val_top_k_categorical_accuracy: 0.9000
# Epoch 30/60
#  - 62s - loss: 1.3309 - accuracy: 0.6019 - top_k_categorical_accuracy: 0.9188 - val_loss: 1.4812 - val_accuracy: 0.5888 - val_top_k_categorical_accuracy: 0.8993
# Epoch 31/60
#  - 64s - loss: 1.3298 - accuracy: 0.6006 - top_k_categorical_accuracy: 0.9190 - val_loss: 1.4742 - val_accuracy: 0.5897 - val_top_k_categorical_accuracy: 0.9009
# Epoch 32/60
#  - 64s - loss: 1.3276 - accuracy: 0.6014 - top_k_categorical_accuracy: 0.9208 - val_loss: 1.4843 - val_accuracy: 0.5894 - val_top_k_categorical_accuracy: 0.8999
# Epoch 33/60
#  - 62s - loss: 1.3259 - accuracy: 0.6014 - top_k_categorical_accuracy: 0.9203 - val_loss: 1.4891 - val_accuracy: 0.5884 - val_top_k_categorical_accuracy: 0.8998
# Epoch 34/60
#  - 63s - loss: 1.3250 - accuracy: 0.6021 - top_k_categorical_accuracy: 0.9207 - val_loss: 1.4893 - val_accuracy: 0.5885 - val_top_k_categorical_accuracy: 0.8991
# Epoch 35/60
#  - 62s - loss: 1.3215 - accuracy: 0.6014 - top_k_categorical_accuracy: 0.9205 - val_loss: 1.4843 - val_accuracy: 0.5879 - val_top_k_categorical_accuracy: 0.8990
# Epoch 36/60
#  - 63s - loss: 1.3219 - accuracy: 0.6022 - top_k_categorical_accuracy: 0.9202 - val_loss: 1.4931 - val_accuracy: 0.5892 - val_top_k_categorical_accuracy: 0.8977
# Epoch 37/60
#  - 66s - loss: 1.3196 - accuracy: 0.6019 - top_k_categorical_accuracy: 0.9200 - val_loss: 1.4980 - val_accuracy: 0.5891 - val_top_k_categorical_accuracy: 0.9004
# Epoch 38/60
#  - 64s - loss: 1.3187 - accuracy: 0.6033 - top_k_categorical_accuracy: 0.9210 - val_loss: 1.4893 - val_accuracy: 0.5887 - val_top_k_categorical_accuracy: 0.8991
# Epoch 39/60
#  - 61s - loss: 1.3167 - accuracy: 0.6022 - top_k_categorical_accuracy: 0.9218 - val_loss: 1.4813 - val_accuracy: 0.5873 - val_top_k_categorical_accuracy: 0.8993
# Epoch 40/60
#  - 64s - loss: 1.3169 - accuracy: 0.6024 - top_k_categorical_accuracy: 0.9215 - val_loss: 1.4917 - val_accuracy: 0.5895 - val_top_k_categorical_accuracy: 0.8996
# Epoch 41/60
#  - 63s - loss: 1.3160 - accuracy: 0.6017 - top_k_categorical_accuracy: 0.9210 - val_loss: 1.4931 - val_accuracy: 0.5894 - val_top_k_categorical_accuracy: 0.8992
# Epoch 42/60
#  - 64s - loss: 1.3154 - accuracy: 0.6030 - top_k_categorical_accuracy: 0.9218 - val_loss: 1.4918 - val_accuracy: 0.5884 - val_top_k_categorical_accuracy: 0.8983
# Epoch 43/60
#  - 63s - loss: 1.3101 - accuracy: 0.6031 - top_k_categorical_accuracy: 0.9222 - val_loss: 1.4947 - val_accuracy: 0.5893 - val_top_k_categorical_accuracy: 0.8999
# Epoch 44/60
#  - 63s - loss: 1.3098 - accuracy: 0.6042 - top_k_categorical_accuracy: 0.9225 - val_loss: 1.4963 - val_accuracy: 0.5878 - val_top_k_categorical_accuracy: 0.8998
# Epoch 45/60
#  - 63s - loss: 1.3094 - accuracy: 0.6030 - top_k_categorical_accuracy: 0.9221 - val_loss: 1.5028 - val_accuracy: 0.5885 - val_top_k_categorical_accuracy: 0.8987
# Epoch 46/60
#  - 63s - loss: 1.3064 - accuracy: 0.6045 - top_k_categorical_accuracy: 0.9226 - val_loss: 1.5011 - val_accuracy: 0.5886 - val_top_k_categorical_accuracy: 0.8990
# Epoch 47/60
#  - 63s - loss: 1.3070 - accuracy: 0.6051 - top_k_categorical_accuracy: 0.9231 - val_loss: 1.5056 - val_accuracy: 0.5881 - val_top_k_categorical_accuracy: 0.8979
# Epoch 48/60
#  - 63s - loss: 1.3055 - accuracy: 0.6044 - top_k_categorical_accuracy: 0.9231 - val_loss: 1.5056 - val_accuracy: 0.5887 - val_top_k_categorical_accuracy: 0.8974
# Epoch 49/60
#  - 63s - loss: 1.3044 - accuracy: 0.6038 - top_k_categorical_accuracy: 0.9232 - val_loss: 1.4971 - val_accuracy: 0.5895 - val_top_k_categorical_accuracy: 0.8992
# Epoch 50/60
#  - 63s - loss: 1.3055 - accuracy: 0.6048 - top_k_categorical_accuracy: 0.9235 - val_loss: 1.5057 - val_accuracy: 0.5889 - val_top_k_categorical_accuracy: 0.8991
# Epoch 51/60
#  - 61s - loss: 1.3011 - accuracy: 0.6048 - top_k_categorical_accuracy: 0.9235 - val_loss: 1.5070 - val_accuracy: 0.5880 - val_top_k_categorical_accuracy: 0.8954
# Epoch 52/60
#  - 64s - loss: 1.3031 - accuracy: 0.6042 - top_k_categorical_accuracy: 0.9238 - val_loss: 1.4965 - val_accuracy: 0.5886 - val_top_k_categorical_accuracy: 0.8995
# Epoch 53/60
#  - 64s - loss: 1.3017 - accuracy: 0.6048 - top_k_categorical_accuracy: 0.9233 - val_loss: 1.5083 - val_accuracy: 0.5875 - val_top_k_categorical_accuracy: 0.8986
# Epoch 54/60
#  - 62s - loss: 1.3002 - accuracy: 0.6054 - top_k_categorical_accuracy: 0.9244 - val_loss: 1.5116 - val_accuracy: 0.5882 - val_top_k_categorical_accuracy: 0.8969
# Epoch 55/60
#  - 62s - loss: 1.2991 - accuracy: 0.6060 - top_k_categorical_accuracy: 0.9236 - val_loss: 1.5011 - val_accuracy: 0.5882 - val_top_k_categorical_accuracy: 0.8985
# Epoch 56/60
#  - 62s - loss: 1.3020 - accuracy: 0.6041 - top_k_categorical_accuracy: 0.9229 - val_loss: 1.5121 - val_accuracy: 0.5874 - val_top_k_categorical_accuracy: 0.8978
# Epoch 57/60
#  - 62s - loss: 1.2978 - accuracy: 0.6062 - top_k_categorical_accuracy: 0.9238 - val_loss: 1.5096 - val_accuracy: 0.5868 - val_top_k_categorical_accuracy: 0.8968
# Epoch 58/60
#  - 61s - loss: 1.2960 - accuracy: 0.6053 - top_k_categorical_accuracy: 0.9244 - val_loss: 1.5094 - val_accuracy: 0.5867 - val_top_k_categorical_accuracy: 0.8980
# Epoch 59/60
#  - 63s - loss: 1.2927 - accuracy: 0.6066 - top_k_categorical_accuracy: 0.9257 - val_loss: 1.5131 - val_accuracy: 0.5880 - val_top_k_categorical_accuracy: 0.8980
# Epoch 60/60
#  - 62s - loss: 1.2945 - accuracy: 0.6066 - top_k_categorical_accuracy: 0.9245 - val_loss: 1.5130 - val_accuracy: 0.5874 - val_top_k_categorical_accuracy: 0.8970

# %% [markdown]
# 实验十：八和九哪个好，就在哪个上面加FilterResponseNormalization，结果是实验九好！

# %%
import tensorflow as tf
from keras import backend as K
 
K.clear_session()
tf.reset_default_graph()
