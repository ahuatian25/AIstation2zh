# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import keras

from keras import layers,metrics
from keras.optimizers import RMSprop
from keras.layers import Dense, LSTM, Dropout, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import PReLU, ELU
from keras.models import Sequential, load_model
from keras.utils import np_utils, multi_gpu_model

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder 
from sklearn.utils import shuffle as reset
from sklearn.model_selection import train_test_split,GridSearchCV,StratifiedShuffleSplit
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import log_loss,make_scorer

from matplotlib.colors import LogNorm
# import 
from matplotlib.pylab import plt
from copy import deepcopy
from datetime import datetime
from imblearn.over_sampling import RandomOverSampler #https://imbalanced-learn.org/stable/generated/imblearn.over_sampling.RandomOverSampler.html?highlight=randomoversampler
from frplayer import FilterResponseNormalization
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def train_test_split_DataFrame(data, test_size=0.2, considerTime=True, random_state=None):
    # ConsiderTime-------trainDF和testDF分割时是否考虑时间问题，即是否需要随机打乱。True:按照‘Dates’列进行降序排列,False：随机打乱样本的顺序，
    if considerTime:
        data=data.sort_values(by="Dates", ascending=True)
    else:
        data=reset(data, random_state=random_state)
    train=data[int(len(data)*test_size):].reset_index(drop=True)
    test=data[:int(len(data)*test_size)].reset_index(drop=True)
    return train, test

# %%
def parse_time(x):
#     if '-' in x:
#         DD=datetime.strptime(x,"%Y-%m-%d %H:%M:%S")#jjs
#     else:
    DD=datetime.strptime(x,"%Y-%m-%d %H:%M")#zj    
    time=DD.hour#*60+DD.minute
    day=DD.day
    month=DD.month
    year=DD.year
    return time,day,month,year
def Dates2TDMY(x):
    if '-' in x:
        DD=datetime.strptime(x,"%Y-%m-%d %H:%M:%S")#jjs
    else:
        DD=datetime.strptime(x,"%Y/%m/%d %H:%M")#zj  
    time=DD.hour#*60+DD.minute
    day=DD.day
    month=DD.month
    year=DD.year
    #T_D_M_Y=str(time)+str(day)+str(month)+str(year)
    T_D_M_Y=str(time)+str(day)+str(month)
    return T_D_M_Y
def get_season(x):
    summer=0
    fall=0
    winter=0
    spring=0
    if (x in [5, 6, 7]):
        summer=1
    if (x in [8, 9, 10]):
        fall=1
    if (x in [11, 0, 1]):
        winter=1
    if (x in [2, 3, 4]):
        spring=1
    return summer, fall, winter, spring

# %%
def field2Vec(trainDF,testDF,fieldStr):
    fields=sorted(trainDF[fieldStr].unique())
    categories=sorted(trainDF["Category"].unique())
    C_counts=trainDF.groupby(["Category"]).size()
    F_C_counts=trainDF.groupby([fieldStr,"Category"]).size()
    F_counts=trainDF.groupby([fieldStr]).size()
    logodds={}
    logoddsPF={}
    MIN_CAT_COUNTS=2
    default_logodds=np.log(C_counts/len(trainDF))-np.log(1.0-C_counts/float(len(trainDF)))
    for f in fields:
        PA=F_counts[f]/float(len(trainDF))
        logoddsPF[f]=np.log(PA)-np.log(1.-PA)
        logodds[f]=deepcopy(default_logodds)
        for cat in F_C_counts[f].keys():
            if (F_C_counts[f][cat]>MIN_CAT_COUNTS) and F_C_counts[f][cat]<F_counts[f]:
                PA=F_C_counts[f][cat]/float(F_counts[f])
                logodds[f][categories.index(cat)]=np.log(PA)-np.log(1.0-PA)
        logodds[f]=pd.Series(logodds[f])
        logodds[f].index=range(len(categories))
    ########此部分代码，从逻辑上不应该出现在此处，但是为了编程的方便，放在了此处#########
    #fieldsTest=sorted(testDF[fieldStr].unique())
    #N_count=0
    #for f in fieldsTest:
        #if f not in fields:
            #logoddsPF[f]=-50.0  #np.log(0.)-np.log(1.)=-inf,便于计算，改为-99999.0
            #logodds[f]=deepcopy(default_logodds)
            #pa=1.0/float(len(categories))
            #logodds[f][range(len(categories))]=np.log(pa)-np.log(1.0-pa)
            #logodds[f]=pd.Series(logodds[f])
            #logodds[f].index=range(len(categories))
            #N_count=N_count+1
    #print(fieldStr+' N_count: '+str(N_count))
    ########此部分代码，从逻辑上不应该出现在此处，但是为了编程的方便，放在了此处#########
    #引进代码原作者的新思想
    if testDF.shape[0]>0: #如果testDF里有样本,......
        new_fields=sorted(testDF[fieldStr].unique())
        new_F_counts=testDF.groupby(fieldStr).size()
        only_new=set(new_fields+fields)-set(fields)
        only_old=set(new_fields+fields)-set(new_fields)
        in_both=set(new_fields).intersection(fields)
        print('# only_new_fieldds:'+str(len(only_new)))
        for f in only_new:
            PA=new_F_counts[f]/float(len(testDF)+len(trainDF))
            logoddsPF[f]=np.log(PA)-np.log(1.-PA)
            logodds[f]=deepcopy(default_logodds)
            logodds[f].index=range(len(categories))
        for f in in_both:
            PA=(F_counts[f]+new_F_counts[f])/float(len(testDF)+len(trainDF))
            logoddsPF[f]=np.log(PA)-np.log(1.-PA)    
    return logodds,logoddsPF

# %%
def parse_data(df,logodds_A,logoddsPF_A,logodds_T,logoddsPF_T,needT_D_M_Y=False):
    feature_list=df.columns.tolist()
    if "Descript" in feature_list:
        feature_list.remove("Descript")
    if "Resolution" in feature_list:
        feature_list.remove("Resolution")
    if "Category" in feature_list:
        feature_list.remove("Category")
    if "Id" in feature_list:
        feature_list.remove("Id")

    cleanData=df[feature_list]
    cleanData.index=range(len(df))
    print("Creating address features")###Creating address features###
    address_features=cleanData["Address"].apply(lambda x: logodds_A[x])
    address_features.columns=["logodds_A"+str(x) for x in range(len(address_features.columns))]
    if needT_D_M_Y:
        print("Creating time T_D_M_Y features")###Creating time T_D_M_Y features###
        T_D_M_Y_features=cleanData["T_D_M_Y"].apply(lambda xx: logodds_T[xx])
        T_D_M_Y_features.columns=["logodds_T"+str(xx) for xx in range(len(T_D_M_Y_features.columns))]

    print("Parsing dates")            ###Creating address features###
    cleanData["Time"], cleanData["Day"], cleanData["Month"], cleanData["Year"]=zip(*cleanData["Dates"].apply(parse_time))
    #     dummy_ranks_DAY = pd.get_dummies(cleanData['DayOfWeek'], prefix='DAY')
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    #     cleanData["DayOfWeek"]=cleanData["DayOfWeek"].apply(lambda x: days.index(x)/float(len(days)))
    print("Creating one-hot variables")
    dummy_ranks_PD = pd.get_dummies(cleanData['PdDistrict'], prefix='PD')
    dummy_ranks_DAY = pd.get_dummies(cleanData["DayOfWeek"], prefix='DAY')
    cleanData["IsInterection"]=cleanData["Address"].apply(lambda x: 1 if "/" in x else 0)
    cleanData["logoddsPF_A"]=cleanData["Address"].apply(lambda x: logoddsPF_A[x])
    if needT_D_M_Y:
        cleanData["logoddsPF_T"]=cleanData["T_D_M_Y"].apply(lambda x: logoddsPF_T[x])
    print("droping processed columns")
    cleanData=cleanData.drop("PdDistrict",axis=1)
    cleanData=cleanData.drop("DayOfWeek",axis=1)
    cleanData=cleanData.drop("Address",axis=1)    
    cleanData=cleanData.drop("Dates",axis=1)
    if needT_D_M_Y:
        cleanData=cleanData.drop("T_D_M_Y",axis=1)
    feature_list=cleanData.columns.tolist()
    print("joining one-hot features")
    if needT_D_M_Y:
        features = cleanData[feature_list].join(dummy_ranks_PD.iloc[:,:]).join(dummy_ranks_DAY.iloc[:,:]).join(address_features.iloc[:,:]).join(T_D_M_Y_features.iloc[:,:])
    else:
        features = cleanData[feature_list].join(dummy_ranks_PD.iloc[:,:]).join(dummy_ranks_DAY.iloc[:,:]).join(address_features.iloc[:,:])
    print("creating new features")
    features["IsDup"]=pd.Series(features.duplicated()|features.duplicated(keep='last')).apply(int)
    features["Awake"]=features["Time"].apply(lambda x: 1 if (x==0 or (x>=8 and x<=23)) else 0)
    features["Summer"], features["Fall"], features["Winter"], features["Spring"]=zip(*features["Month"].apply(get_season))
    if "Category" in df.columns:
        labels = df["Category"].astype('category')
    else:
        labels=None
    return features,labels

# %%
def generator(X, Y, lookback, delay, min_index, max_index, shuffle=False, batch_size=128, step=6):
    if max_index is None:
        max_index = len(X) - delay - 1
    i = min_index + lookback
    while 1:
        if shuffle:
            rows = np.random.randint(min_index + lookback, max_index, size=batch_size)
        else:
            if i + batch_size >= max_index:
                i = min_index + lookback
            rows = np.arange(i, min(i + batch_size, max_index))
            i += len(rows)

        samples = np.zeros((len(rows), lookback // step, X.shape[-1]))
        targets = np.zeros((len(rows),Y.shape[1]))
        for j, row in enumerate(rows):
            indices = range(rows[j] - lookback, rows[j], step)
            samples[j] = X[indices]
            targets[j] = Y[rows[j]+delay]
        yield samples, targets
    #Now here is the data generator that we will use. It yields a tuple (samples, targets) where samples is one batch of input data and targets is the corresponding array of target temperatures. It takes the following arguments:
        # •data: The original array of floating point data, which we just normalized in the code snippet above.
        # •lookback: How many timesteps back should our input data go.
        # •delay: How many timesteps in the future should our target be.
        # •min_index and max_index: Indices in the data array that delimit which timesteps to draw from. This is useful for keeping a segment of the data for validation and another one for testing.
        # •shuffle: Whether to shuffle our samples or draw them in chronological order.
        # •batch_size: The number of samples per batch.
        # •step: The period, in timesteps, at which we sample data. We will set it 6 in order to draw one data point every hour.

# %%
#Import data
ConsiderTime=False# True##trainDF和testDF分割时是否考虑时间问题，即是否需要随机打乱。True:按照‘Dates’列进行降序排列,False：随机打乱样本的顺序，
Rate_ALL=0.0 #0.0即不保留测试机
needOverSampler=False
needT_D_M_Y=False
allDF=pd.read_csv("./HuZhou.csv")
print('The shape of OrginalAllDF: '+str(allDF.shape))

xy_scaler=preprocessing.StandardScaler()
xy_scaler.fit(allDF[["X","Y"]])
allDF[["X","Y"]]=xy_scaler.transform(allDF[["X","Y"]])
allDF=allDF[abs(allDF["Y"])<100]
allDF.index=range(len(allDF))
print('The shape of AllDF after del wrong X and Y values: '+str(allDF.shape))

def listCat(x):
    return list(x)
allDF.drop_duplicates(inplace=True,subset=['Dates', 'DayOfWeek', 'PdDistrict', 'Address', 'X', 'Y', 'Category'])
Train_duplicated=pd.pivot_table(allDF,index=['Dates','DayOfWeek','PdDistrict', 'Address', 'X', 'Y'], values='Category',aggfunc=[len,listCat])
print('The shape of AllDF after drop_duplicates: '+str(allDF.shape))
print(Train_duplicated.shape)

trainDF,testDF=train_test_split_DataFrame(allDF, test_size=Rate_ALL, considerTime=ConsiderTime, random_state=None)
print('Address_counts_allDF_trainDF_testDF: ' + str(len(allDF["Address"].unique())) + '_'+ str(len(trainDF["Address"].unique())) + '_' + str(len(testDF["Address"].unique())))

N_AllSample=allDF.shape[0]
N_AllTrain=trainDF.shape[0]
N_AllTest=testDF.shape[0]
N_CLASS=len(allDF["Category"].unique())
print('The # of AllDF, AllTrain, AllTest, is: '+str(N_AllSample)+','+str(N_AllTrain)+','+str(N_AllTest))
#################Now proceed as before#################
print('-----------LOGOODS: Address-------------')
logodds_A,logoddsPF_A=field2Vec(trainDF,testDF,"Address")
if needT_D_M_Y:
    trainDF["T_D_M_Y"]=trainDF["Dates"].apply(Dates2TDMY)
    trainDF["T_D_M_Y"]=trainDF["T_D_M_Y"]+trainDF["DayOfWeek"]
    if Rate_ALL>0:
        testDF[["X","Y"]]=xy_scaler.transform(testDF[["X","Y"]])
        testDF["T_D_M_Y"]=testDF["Dates"].apply(Dates2TDMY)
        testDF["T_D_M_Y"]=testDF["T_D_M_Y"]+testDF["DayOfWeek"]
    print('-----------LOGOODS: T_D_M_Y-------------')
    logodds_T,logoddsPF_T=field2Vec(trainDF,testDF,"T_D_M_Y")    
else:
    logodds_T=None
    logoddsPF_T=None
    
print('-----------LOGOODS: parse_data of Alltrain  -------------')
features, labels=parse_data(trainDF,logodds_A,logoddsPF_A,logodds_T,logoddsPF_T,needT_D_M_Y) 
if Rate_ALL>0:
    print('-----------LOGOODS: parse_data of Alltest  -------------')
    features_test, labels_test=parse_data(testDF,logodds_A,logoddsPF_A,logodds_T,logoddsPF_T,needT_D_M_Y)###########和训练集使用同样的时间和地点Logoodds值#####
    x_test=features_test.values
    y_test=labels_test.values
    y_test = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_test)), num_classes=N_CLASS)

print(features.columns.tolist())
print(len(features.columns))

collist=features.columns.tolist()
scaler = preprocessing.StandardScaler()
scaler.fit(features)
features[collist]=scaler.transform(features)
if Rate_ALL>0:
    features_test[collist]=scaler.transform(features_test)###########和训练集使用同样的scaler值#####
######################################################
#############################先进行过采样，然后再根据时间来排序##################################
if needOverSampler:
    print('------------RandomOverSampler--------------')
    ros = RandomOverSampler()
    featuresArrayOverSampler, labelsArrayOverSampler = ros.fit_resample(features.values,labels.values)#####过采样#####
    N_AllTrain_OverSampler=int(featuresArrayOverSampler.shape[0])
    print('Shape of OverSampler of AllTrain: '+str(featuresArrayOverSampler.shape))
else:
    featuresArrayOverSampler=features.values
    labelsArrayOverSampler=labels.values
    N_AllTrain_OverSampler=int(featuresArrayOverSampler.shape[0])
    print('------------Attention: we do not RandomOverSampler---------------')
if ConsiderTime:
    #####按照年（第6列）月（第5列）日（第4列）时（第3列）排序
    print('------------Sort--------------')
    time_temp=featuresArrayOverSampler[:,2]+np.dot(featuresArrayOverSampler[:,3],100)+np.dot(featuresArrayOverSampler[:,4],10000)+np.dot(featuresArrayOverSampler[:,5],1000000)
    features_label_time=np.column_stack((featuresArrayOverSampler,labelsArrayOverSampler))
    features_label_time=np.column_stack((features_label_time,time_temp))
    features_label_time =features_label_time[np.argsort(features_label_time[:,-1])]
    labelsArrayOverSampler=features_label_time[:,-2]
    featuresArrayOverSampler=features_label_time[:,0:featuresArrayOverSampler.shape[1]]
    del features_label_time
    #############################先进行过采样，然后再根据时间来排序----结束############################
# Out:
# The shape of OrginalAllDF: (145962, 9)
# The shape of AllDF after del wrong X and Y values: (145960, 9)
# The shape of AllDF after drop_duplicates: (145876, 9)
# (145859, 2)
# Address_counts_allDF_trainDF_testDF: 17161_17161_0
# The # of AllDF, AllTrain, AllTest, is: 145876,145876,0
# -----------LOGOODS: Address-------------
# -----------LOGOODS: parse_data of Alltrain  -------------
# Creating address features
# Parsing dates
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Creating one-hot variables
# droping processed columns
# joining one-hot features
# creating new features
# ['X', 'Y', 'Time', 'Day', 'Month', 'Year', 'IsInterection', 'logoddsPF_A', 'PD_星期一', 'PD_星期三', 'PD_星期二', 'PD_星期五', 'PD_星期六', 'PD_星期四', 'PD_星期日', 'DAY_星期一', 'DAY_星期三', 'DAY_星期二', 'DAY_星期五', 'DAY_星期六', 'DAY_星期四', 'DAY_星期日', 'logodds_A0', 'logodds_A1', 'logodds_A2', 'logodds_A3', 'logodds_A4', 'logodds_A5', 'logodds_A6', 'logodds_A7', 'logodds_A8', 'logodds_A9', 'logodds_A10', 'logodds_A11', 'logodds_A12', 'logodds_A13', 'logodds_A14', 'logodds_A15', 'logodds_A16', 'logodds_A17', 'logodds_A18', 'logodds_A19', 'logodds_A20', 'logodds_A21', 'logodds_A22', 'logodds_A23', 'logodds_A24', 'logodds_A25', 'logodds_A26', 'logodds_A27', 'logodds_A28', 'logodds_A29', 'logodds_A30', 'logodds_A31', 'logodds_A32', 'logodds_A33', 'logodds_A34', 'logodds_A35', 'logodds_A36', 'logodds_A37', 'logodds_A38', 'logodds_A39', 'logodds_A40', 'logodds_A41', 'logodds_A42', 'logodds_A43', 'logodds_A44', 'logodds_A45', 'logodds_A46', 'logodds_A47', 'logodds_A48', 'logodds_A49', 'IsDup', 'Awake', 'Summer', 'Fall', 'Winter', 'Spring']
# 78
# ------------Attention: we do not RandomOverSampler---------------

# %%
if Rate_ALL>0:
    print('------------RandomOverSampler for AllTest--------------')
    ros = RandomOverSampler()
    featuresArray_test, labelsArray_test = ros.fit_resample(features_test.values,labels_test.values)#####过采样#####
    N_AllTest_OverSampler=int(featuresArray_test.shape[0])
    labelsArray_test = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(labelsArray_test)), num_classes=N_CLASS)
    print('Shape of OverSampler of AllTest: '+str(featuresArray_test.shape))

# %% [markdown]
# 实验三、完全重现Kaggle第十一名的代码的基础上，改变BAD为AB，其中B改为FilterResponseNormalization

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=50
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=64
dp=0.5
Rate_Val=0.5
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
# model.add(Dense(N_HN_1,input_dim=input_dim))
# model.add(PReLU())
# model.add(Dropout(dp))
# for i in range(N_LAYERS):
#     model.add(Dense(N_HN))
#     model.add(PReLU())
#     model.add(BatchNormalization())   
#     model.add(Dropout(dp))
# model.add(Dense(output_dim))
# model.add(Activation('softmax'))
# model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])

model.add(Dense(N_HN_1,input_dim=input_dim))
# model.add(BatchNormalization())
model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
# model.add(Dropout(dp))
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
#     model.add(BatchNormalization())   
    model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
#   model.add(Dropout(dp))
# model.add(BatchNormalization())
model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
# model = multi_gpu_model(model, 2)gfyht76```
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])



x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)
# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####


y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
# fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)

# acc_test, test_score,fitting, model = build_and_fit_model(features_train.values,labels_train,x_val=features_test.values,y_test=labels_test,hn=N_HN,layers=N_LAYERS,epochs=N_EPOCHS,verbose=2,dp=DP)
# model.save('jjs_model_0124V3.h5')
# Out:
# ------------Building DNN model--------------
# ------------DNN Training Go! Go! Go!!!!-----------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 72938 samples, validate on 72938 samples
# Epoch 1/50
#  - 16s - loss: 1.6209 - accuracy: 0.5527 - top_k_categorical_accuracy: 0.8819 - val_loss: 1.5337 - val_accuracy: 0.5666 - val_top_k_categorical_accuracy: 0.8949
# Epoch 2/50
#  - 14s - loss: 1.5269 - accuracy: 0.5640 - top_k_categorical_accuracy: 0.8963 - val_loss: 1.5194 - val_accuracy: 0.5689 - val_top_k_categorical_accuracy: 0.8989
# Epoch 3/50
#  - 14s - loss: 1.5031 - accuracy: 0.5670 - top_k_categorical_accuracy: 0.9000 - val_loss: 1.5075 - val_accuracy: 0.5691 - val_top_k_categorical_accuracy: 0.8986
# Epoch 4/50
#  - 14s - loss: 1.4877 - accuracy: 0.5690 - top_k_categorical_accuracy: 0.9020 - val_loss: 1.5039 - val_accuracy: 0.5731 - val_top_k_categorical_accuracy: 0.9016
# Epoch 5/50
#  - 14s - loss: 1.4773 - accuracy: 0.5705 - top_k_categorical_accuracy: 0.9035 - val_loss: 1.4985 - val_accuracy: 0.5719 - val_top_k_categorical_accuracy: 0.8993
# Epoch 6/50
#  - 14s - loss: 1.4669 - accuracy: 0.5719 - top_k_categorical_accuracy: 0.9050 - val_loss: 1.4907 - val_accuracy: 0.5732 - val_top_k_categorical_accuracy: 0.9021
# Epoch 7/50
#  - 13s - loss: 1.4582 - accuracy: 0.5738 - top_k_categorical_accuracy: 0.9060 - val_loss: 1.4882 - val_accuracy: 0.5721 - val_top_k_categorical_accuracy: 0.9018
# Epoch 8/50
#  - 13s - loss: 1.4492 - accuracy: 0.5741 - top_k_categorical_accuracy: 0.9077 - val_loss: 1.4896 - val_accuracy: 0.5711 - val_top_k_categorical_accuracy: 0.9024
# Epoch 9/50
#  - 13s - loss: 1.4424 - accuracy: 0.5765 - top_k_categorical_accuracy: 0.9084 - val_loss: 1.4952 - val_accuracy: 0.5688 - val_top_k_categorical_accuracy: 0.9007
# Epoch 10/50
#  - 13s - loss: 1.4341 - accuracy: 0.5770 - top_k_categorical_accuracy: 0.9092 - val_loss: 1.4920 - val_accuracy: 0.5732 - val_top_k_categorical_accuracy: 0.9007
# Epoch 11/50
#  - 15s - loss: 1.4249 - accuracy: 0.5794 - top_k_categorical_accuracy: 0.9109 - val_loss: 1.4924 - val_accuracy: 0.5735 - val_top_k_categorical_accuracy: 0.9013
# Epoch 12/50
#  - 14s - loss: 1.4167 - accuracy: 0.5802 - top_k_categorical_accuracy: 0.9116 - val_loss: 1.4973 - val_accuracy: 0.5722 - val_top_k_categorical_accuracy: 0.9003
# Epoch 13/50
#  - 15s - loss: 1.4079 - accuracy: 0.5804 - top_k_categorical_accuracy: 0.9128 - val_loss: 1.5003 - val_accuracy: 0.5727 - val_top_k_categorical_accuracy: 0.9000
# Epoch 14/50
#  - 14s - loss: 1.3990 - accuracy: 0.5814 - top_k_categorical_accuracy: 0.9142 - val_loss: 1.5108 - val_accuracy: 0.5706 - val_top_k_categorical_accuracy: 0.9001
# Epoch 15/50
#  - 14s - loss: 1.3908 - accuracy: 0.5832 - top_k_categorical_accuracy: 0.9154 - val_loss: 1.5088 - val_accuracy: 0.5727 - val_top_k_categorical_accuracy: 0.8987
# Epoch 16/50
#  - 13s - loss: 1.3818 - accuracy: 0.5853 - top_k_categorical_accuracy: 0.9175 - val_loss: 1.5200 - val_accuracy: 0.5673 - val_top_k_categorical_accuracy: 0.8973
# Epoch 17/50
#  - 15s - loss: 1.3731 - accuracy: 0.5861 - top_k_categorical_accuracy: 0.9185 - val_loss: 1.5272 - val_accuracy: 0.5670 - val_top_k_categorical_accuracy: 0.8971
# Epoch 18/50
#  - 14s - loss: 1.3648 - accuracy: 0.5875 - top_k_categorical_accuracy: 0.9189 - val_loss: 1.5387 - val_accuracy: 0.5680 - val_top_k_categorical_accuracy: 0.8949
# Epoch 19/50
#  - 13s - loss: 1.3576 - accuracy: 0.5885 - top_k_categorical_accuracy: 0.9205 - val_loss: 1.5411 - val_accuracy: 0.5686 - val_top_k_categorical_accuracy: 0.8965
# Epoch 20/50
#  - 14s - loss: 1.3503 - accuracy: 0.5908 - top_k_categorical_accuracy: 0.9212 - val_loss: 1.5559 - val_accuracy: 0.5658 - val_top_k_categorical_accuracy: 0.8946
# Epoch 21/50
#  - 14s - loss: 1.3442 - accuracy: 0.5915 - top_k_categorical_accuracy: 0.9230 - val_loss: 1.5463 - val_accuracy: 0.5683 - val_top_k_categorical_accuracy: 0.8957
# Epoch 22/50
#  - 14s - loss: 1.3359 - accuracy: 0.5936 - top_k_categorical_accuracy: 0.9231 - val_loss: 1.5579 - val_accuracy: 0.5618 - val_top_k_categorical_accuracy: 0.8927
# Epoch 23/50
#  - 14s - loss: 1.3287 - accuracy: 0.5947 - top_k_categorical_accuracy: 0.9247 - val_loss: 1.5646 - val_accuracy: 0.5641 - val_top_k_categorical_accuracy: 0.8920
# Epoch 24/50
#  - 14s - loss: 1.3229 - accuracy: 0.5954 - top_k_categorical_accuracy: 0.9253 - val_loss: 1.5696 - val_accuracy: 0.5670 - val_top_k_categorical_accuracy: 0.8934
# Epoch 25/50
#  - 14s - loss: 1.3173 - accuracy: 0.5960 - top_k_categorical_accuracy: 0.9267 - val_loss: 1.5835 - val_accuracy: 0.5610 - val_top_k_categorical_accuracy: 0.8915
# Epoch 26/50
#  - 13s - loss: 1.3115 - accuracy: 0.5975 - top_k_categorical_accuracy: 0.9270 - val_loss: 1.5851 - val_accuracy: 0.5632 - val_top_k_categorical_accuracy: 0.8925
# Epoch 27/50
#  - 14s - loss: 1.3063 - accuracy: 0.5993 - top_k_categorical_accuracy: 0.9283 - val_loss: 1.5941 - val_accuracy: 0.5636 - val_top_k_categorical_accuracy: 0.8915
# Epoch 28/50
#  - 14s - loss: 1.3010 - accuracy: 0.5997 - top_k_categorical_accuracy: 0.9286 - val_loss: 1.6093 - val_accuracy: 0.5570 - val_top_k_categorical_accuracy: 0.8900
# Epoch 29/50
#  - 13s - loss: 1.2955 - accuracy: 0.6011 - top_k_categorical_accuracy: 0.9289 - val_loss: 1.6119 - val_accuracy: 0.5600 - val_top_k_categorical_accuracy: 0.8894
# Epoch 30/50
#  - 14s - loss: 1.2910 - accuracy: 0.6019 - top_k_categorical_accuracy: 0.9295 - val_loss: 1.6176 - val_accuracy: 0.5575 - val_top_k_categorical_accuracy: 0.8896
# Epoch 31/50
#  - 14s - loss: 1.2870 - accuracy: 0.6027 - top_k_categorical_accuracy: 0.9294 - val_loss: 1.6144 - val_accuracy: 0.5568 - val_top_k_categorical_accuracy: 0.8906
# Epoch 32/50
#  - 14s - loss: 1.2819 - accuracy: 0.6042 - top_k_categorical_accuracy: 0.9302 - val_loss: 1.6265 - val_accuracy: 0.5610 - val_top_k_categorical_accuracy: 0.8885
# Epoch 33/50
#  - 14s - loss: 1.2776 - accuracy: 0.6053 - top_k_categorical_accuracy: 0.9315 - val_loss: 1.6369 - val_accuracy: 0.5599 - val_top_k_categorical_accuracy: 0.8886
# Epoch 34/50
#  - 14s - loss: 1.2740 - accuracy: 0.6060 - top_k_categorical_accuracy: 0.9315 - val_loss: 1.6526 - val_accuracy: 0.5594 - val_top_k_categorical_accuracy: 0.8867
# Epoch 35/50
#  - 14s - loss: 1.2698 - accuracy: 0.6066 - top_k_categorical_accuracy: 0.9323 - val_loss: 1.6470 - val_accuracy: 0.5540 - val_top_k_categorical_accuracy: 0.8881
# Epoch 36/50
#  - 14s - loss: 1.2653 - accuracy: 0.6085 - top_k_categorical_accuracy: 0.9334 - val_loss: 1.6475 - val_accuracy: 0.5549 - val_top_k_categorical_accuracy: 0.8881
# Epoch 37/50
#  - 14s - loss: 1.2624 - accuracy: 0.6089 - top_k_categorical_accuracy: 0.9333 - val_loss: 1.6533 - val_accuracy: 0.5517 - val_top_k_categorical_accuracy: 0.8865
# Epoch 38/50
#  - 14s - loss: 1.2598 - accuracy: 0.6088 - top_k_categorical_accuracy: 0.9337 - val_loss: 1.6757 - val_accuracy: 0.5513 - val_top_k_categorical_accuracy: 0.8845
# Epoch 39/50
#  - 14s - loss: 1.2561 - accuracy: 0.6107 - top_k_categorical_accuracy: 0.9329 - val_loss: 1.6713 - val_accuracy: 0.5533 - val_top_k_categorical_accuracy: 0.8859
# Epoch 40/50
#  - 14s - loss: 1.2523 - accuracy: 0.6098 - top_k_categorical_accuracy: 0.9341 - val_loss: 1.6824 - val_accuracy: 0.5541 - val_top_k_categorical_accuracy: 0.8863
# Epoch 41/50
#  - 14s - loss: 1.2489 - accuracy: 0.6109 - top_k_categorical_accuracy: 0.9346 - val_loss: 1.6822 - val_accuracy: 0.5524 - val_top_k_categorical_accuracy: 0.8861
# Epoch 42/50
#  - 14s - loss: 1.2455 - accuracy: 0.6125 - top_k_categorical_accuracy: 0.9350 - val_loss: 1.6925 - val_accuracy: 0.5514 - val_top_k_categorical_accuracy: 0.8851
# Epoch 43/50
#  - 14s - loss: 1.2421 - accuracy: 0.6143 - top_k_categorical_accuracy: 0.9357 - val_loss: 1.7075 - val_accuracy: 0.5441 - val_top_k_categorical_accuracy: 0.8822
# Epoch 44/50
#  - 14s - loss: 1.2389 - accuracy: 0.6138 - top_k_categorical_accuracy: 0.9355 - val_loss: 1.7068 - val_accuracy: 0.5495 - val_top_k_categorical_accuracy: 0.8849
# Epoch 45/50
#  - 14s - loss: 1.2364 - accuracy: 0.6150 - top_k_categorical_accuracy: 0.9360 - val_loss: 1.7069 - val_accuracy: 0.5512 - val_top_k_categorical_accuracy: 0.8844
# Epoch 46/50
#  - 15s - loss: 1.2335 - accuracy: 0.6160 - top_k_categorical_accuracy: 0.9360 - val_loss: 1.7244 - val_accuracy: 0.5419 - val_top_k_categorical_accuracy: 0.8799
# Epoch 47/50
#  - 14s - loss: 1.2304 - accuracy: 0.6168 - top_k_categorical_accuracy: 0.9358 - val_loss: 1.7265 - val_accuracy: 0.5501 - val_top_k_categorical_accuracy: 0.8826
# Epoch 48/50
#  - 14s - loss: 1.2279 - accuracy: 0.6169 - top_k_categorical_accuracy: 0.9364 - val_loss: 1.7138 - val_accuracy: 0.5488 - val_top_k_categorical_accuracy: 0.8832
# Epoch 49/50
#  - 14s - loss: 1.2241 - accuracy: 0.6188 - top_k_categorical_accuracy: 0.9367 - val_loss: 1.7433 - val_accuracy: 0.5502 - val_top_k_categorical_accuracy: 0.8821
# Epoch 50/50
#  - 14s - loss: 1.2226 - accuracy: 0.6191 - top_k_categorical_accuracy: 0.9374 - val_loss: 1.7421 - val_accuracy: 0.5496 - val_top_k_categorical_accuracy: 0.8815

# %%
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC.png')
plt.show()

# %% [markdown]
# 实验四、完全重现Kaggle第十一名的代码

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=50
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=64
dp=0.5
Rate_Val=0.5
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(PReLU())
model.add(Dropout(dp))
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(PReLU())
    model.add(BatchNormalization())   
    model.add(Dropout(dp))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])

# x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)
# # ros_train = RandomOverSampler()
# # x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# # ros_val = RandomOverSampler()
# # x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####

# y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
# y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
# fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)

# acc_test, test_score,fitting, model = build_and_fit_model(features_train.values,labels_train,x_val=features_test.values,y_test=labels_test,hn=N_HN,layers=N_LAYERS,epochs=N_EPOCHS,verbose=2,dp=DP)
model.save('jjs_model_0124V4.h5')
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS1.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC1.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC1.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 406265 samples, validate on 406264 samples
# Epoch 1/50
#  - 118s - loss: 2.4504 - accuracy: 0.2800 - top_k_categorical_accuracy: 0.6801 - val_loss: 2.2648 - val_accuracy: 0.3064 - val_top_k_categorical_accuracy: 0.7237
# Epoch 2/50
#  - 116s - loss: 2.3150 - accuracy: 0.2976 - top_k_categorical_accuracy: 0.7115 - val_loss: 2.2493 - val_accuracy: 0.3095 - val_top_k_categorical_accuracy: 0.7287
# Epoch 3/50
#  - 115s - loss: 2.3015 - accuracy: 0.2992 - top_k_categorical_accuracy: 0.7150 - val_loss: 2.2460 - val_accuracy: 0.3110 - val_top_k_categorical_accuracy: 0.7287
# Epoch 4/50
#  - 113s - loss: 2.2970 - accuracy: 0.3008 - top_k_categorical_accuracy: 0.7164 - val_loss: 2.2433 - val_accuracy: 0.3116 - val_top_k_categorical_accuracy: 0.7295
# Epoch 5/50
#  - 113s - loss: 2.2917 - accuracy: 0.3018 - top_k_categorical_accuracy: 0.7174 - val_loss: 2.2422 - val_accuracy: 0.3108 - val_top_k_categorical_accuracy: 0.7305
# Epoch 6/50
#  - 113s - loss: 2.2897 - accuracy: 0.3019 - top_k_categorical_accuracy: 0.7184 - val_loss: 2.2405 - val_accuracy: 0.3115 - val_top_k_categorical_accuracy: 0.7304
# Epoch 7/50
#  - 111s - loss: 2.2860 - accuracy: 0.3025 - top_k_categorical_accuracy: 0.7188 - val_loss: 2.2391 - val_accuracy: 0.3122 - val_top_k_categorical_accuracy: 0.7308
# Epoch 8/50
#  - 112s - loss: 2.2845 - accuracy: 0.3032 - top_k_categorical_accuracy: 0.7193 - val_loss: 2.2382 - val_accuracy: 0.3107 - val_top_k_categorical_accuracy: 0.7325
# Epoch 9/50
#  - 114s - loss: 2.2823 - accuracy: 0.3033 - top_k_categorical_accuracy: 0.7196 - val_loss: 2.2363 - val_accuracy: 0.3126 - val_top_k_categorical_accuracy: 0.7312
# Epoch 10/50
#  - 115s - loss: 2.2821 - accuracy: 0.3036 - top_k_categorical_accuracy: 0.7199 - val_loss: 2.2353 - val_accuracy: 0.3137 - val_top_k_categorical_accuracy: 0.7321
# Epoch 11/50
#  - 113s - loss: 2.2801 - accuracy: 0.3033 - top_k_categorical_accuracy: 0.7203 - val_loss: 2.2335 - val_accuracy: 0.3139 - val_top_k_categorical_accuracy: 0.7327
# Epoch 12/50
#  - 114s - loss: 2.2777 - accuracy: 0.3048 - top_k_categorical_accuracy: 0.7210 - val_loss: 2.2326 - val_accuracy: 0.3127 - val_top_k_categorical_accuracy: 0.7329
# Epoch 13/50
#  - 112s - loss: 2.2769 - accuracy: 0.3043 - top_k_categorical_accuracy: 0.7218 - val_loss: 2.2299 - val_accuracy: 0.3147 - val_top_k_categorical_accuracy: 0.7343
# Epoch 14/50
#  - 114s - loss: 2.2764 - accuracy: 0.3047 - top_k_categorical_accuracy: 0.7216 - val_loss: 2.2299 - val_accuracy: 0.3139 - val_top_k_categorical_accuracy: 0.7339
# Epoch 15/50
#  - 114s - loss: 2.2752 - accuracy: 0.3055 - top_k_categorical_accuracy: 0.7217 - val_loss: 2.2312 - val_accuracy: 0.3140 - val_top_k_categorical_accuracy: 0.7334
# Epoch 16/50
#  - 114s - loss: 2.2754 - accuracy: 0.3049 - top_k_categorical_accuracy: 0.7212 - val_loss: 2.2299 - val_accuracy: 0.3142 - val_top_k_categorical_accuracy: 0.7342
# Epoch 17/50
#  - 114s - loss: 2.2750 - accuracy: 0.3045 - top_k_categorical_accuracy: 0.7218 - val_loss: 2.2285 - val_accuracy: 0.3138 - val_top_k_categorical_accuracy: 0.7349
# Epoch 18/50
#  - 112s - loss: 2.2757 - accuracy: 0.3042 - top_k_categorical_accuracy: 0.7212 - val_loss: 2.2278 - val_accuracy: 0.3153 - val_top_k_categorical_accuracy: 0.7347
# Epoch 19/50
#  - 115s - loss: 2.2736 - accuracy: 0.3049 - top_k_categorical_accuracy: 0.7217 - val_loss: 2.2280 - val_accuracy: 0.3153 - val_top_k_categorical_accuracy: 0.7341
# Epoch 20/50
#  - 114s - loss: 2.2730 - accuracy: 0.3054 - top_k_categorical_accuracy: 0.7221 - val_loss: 2.2300 - val_accuracy: 0.3143 - val_top_k_categorical_accuracy: 0.7340
# Epoch 21/50
#  - 113s - loss: 2.2733 - accuracy: 0.3049 - top_k_categorical_accuracy: 0.7216 - val_loss: 2.2288 - val_accuracy: 0.3139 - val_top_k_categorical_accuracy: 0.7348
# Epoch 22/50
#  - 111s - loss: 2.2717 - accuracy: 0.3053 - top_k_categorical_accuracy: 0.7225 - val_loss: 2.2262 - val_accuracy: 0.3152 - val_top_k_categorical_accuracy: 0.7352
# Epoch 23/50
#  - 109s - loss: 2.2717 - accuracy: 0.3057 - top_k_categorical_accuracy: 0.7222 - val_loss: 2.2282 - val_accuracy: 0.3138 - val_top_k_categorical_accuracy: 0.7343
# Epoch 24/50
#  - 110s - loss: 2.2725 - accuracy: 0.3048 - top_k_categorical_accuracy: 0.7219 - val_loss: 2.2272 - val_accuracy: 0.3142 - val_top_k_categorical_accuracy: 0.7350
# Epoch 25/50
#  - 111s - loss: 2.2730 - accuracy: 0.3058 - top_k_categorical_accuracy: 0.7214 - val_loss: 2.2256 - val_accuracy: 0.3153 - val_top_k_categorical_accuracy: 0.7355
# Epoch 26/50
#  - 111s - loss: 2.2714 - accuracy: 0.3047 - top_k_categorical_accuracy: 0.7225 - val_loss: 2.2251 - val_accuracy: 0.3157 - val_top_k_categorical_accuracy: 0.7352
# Epoch 27/50
#  - 111s - loss: 2.2716 - accuracy: 0.3051 - top_k_categorical_accuracy: 0.7227 - val_loss: 2.2267 - val_accuracy: 0.3148 - val_top_k_categorical_accuracy: 0.7347
# Epoch 28/50
#  - 114s - loss: 2.2709 - accuracy: 0.3056 - top_k_categorical_accuracy: 0.7224 - val_loss: 2.2250 - val_accuracy: 0.3156 - val_top_k_categorical_accuracy: 0.7348
# Epoch 29/50
#  - 112s - loss: 2.2704 - accuracy: 0.3051 - top_k_categorical_accuracy: 0.7235 - val_loss: 2.2254 - val_accuracy: 0.3151 - val_top_k_categorical_accuracy: 0.7354
# Epoch 30/50
#  - 111s - loss: 2.2712 - accuracy: 0.3059 - top_k_categorical_accuracy: 0.7220 - val_loss: 2.2249 - val_accuracy: 0.3154 - val_top_k_categorical_accuracy: 0.7353
# Epoch 31/50
#  - 111s - loss: 2.2704 - accuracy: 0.3051 - top_k_categorical_accuracy: 0.7227 - val_loss: 2.2249 - val_accuracy: 0.3161 - val_top_k_categorical_accuracy: 0.7355
# Epoch 32/50
#  - 110s - loss: 2.2702 - accuracy: 0.3056 - top_k_categorical_accuracy: 0.7228 - val_loss: 2.2243 - val_accuracy: 0.3156 - val_top_k_categorical_accuracy: 0.7353
# Epoch 33/50
#  - 110s - loss: 2.2700 - accuracy: 0.3060 - top_k_categorical_accuracy: 0.7224 - val_loss: 2.2238 - val_accuracy: 0.3152 - val_top_k_categorical_accuracy: 0.7354
# Epoch 34/50
#  - 110s - loss: 2.2696 - accuracy: 0.3053 - top_k_categorical_accuracy: 0.7225 - val_loss: 2.2234 - val_accuracy: 0.3153 - val_top_k_categorical_accuracy: 0.7357
# Epoch 35/50
#  - 110s - loss: 2.2691 - accuracy: 0.3057 - top_k_categorical_accuracy: 0.7235 - val_loss: 2.2275 - val_accuracy: 0.3144 - val_top_k_categorical_accuracy: 0.7346
# Epoch 36/50
#  - 110s - loss: 2.2694 - accuracy: 0.3053 - top_k_categorical_accuracy: 0.7230 - val_loss: 2.2242 - val_accuracy: 0.3156 - val_top_k_categorical_accuracy: 0.7356
# Epoch 37/50
#  - 113s - loss: 2.2699 - accuracy: 0.3053 - top_k_categorical_accuracy: 0.7223 - val_loss: 2.2249 - val_accuracy: 0.3144 - val_top_k_categorical_accuracy: 0.7353
# Epoch 38/50
#  - 113s - loss: 2.2689 - accuracy: 0.3063 - top_k_categorical_accuracy: 0.7231 - val_loss: 2.2223 - val_accuracy: 0.3164 - val_top_k_categorical_accuracy: 0.7363
# Epoch 39/50
#  - 110s - loss: 2.2690 - accuracy: 0.3051 - top_k_categorical_accuracy: 0.7238 - val_loss: 2.2224 - val_accuracy: 0.3159 - val_top_k_categorical_accuracy: 0.7364
# Epoch 40/50
#  - 111s - loss: 2.2687 - accuracy: 0.3060 - top_k_categorical_accuracy: 0.7234 - val_loss: 2.2221 - val_accuracy: 0.3158 - val_top_k_categorical_accuracy: 0.7363
# Epoch 41/50
#  - 112s - loss: 2.2687 - accuracy: 0.3062 - top_k_categorical_accuracy: 0.7239 - val_loss: 2.2229 - val_accuracy: 0.3154 - val_top_k_categorical_accuracy: 0.7354
# Epoch 42/50
#  - 112s - loss: 2.2683 - accuracy: 0.3064 - top_k_categorical_accuracy: 0.7228 - val_loss: 2.2230 - val_accuracy: 0.3155 - val_top_k_categorical_accuracy: 0.7357
# Epoch 43/50
#  - 111s - loss: 2.2683 - accuracy: 0.3064 - top_k_categorical_accuracy: 0.7241 - val_loss: 2.2238 - val_accuracy: 0.3160 - val_top_k_categorical_accuracy: 0.7360
# Epoch 44/50
#  - 109s - loss: 2.2690 - accuracy: 0.3056 - top_k_categorical_accuracy: 0.7228 - val_loss: 2.2249 - val_accuracy: 0.3158 - val_top_k_categorical_accuracy: 0.7351
# Epoch 45/50
#  - 112s - loss: 2.2689 - accuracy: 0.3065 - top_k_categorical_accuracy: 0.7223 - val_loss: 2.2241 - val_accuracy: 0.3160 - val_top_k_categorical_accuracy: 0.7353
# Epoch 46/50
#  - 111s - loss: 2.2675 - accuracy: 0.3068 - top_k_categorical_accuracy: 0.7232 - val_loss: 2.2238 - val_accuracy: 0.3156 - val_top_k_categorical_accuracy: 0.7355
# Epoch 47/50
#  - 110s - loss: 2.2680 - accuracy: 0.3059 - top_k_categorical_accuracy: 0.7232 - val_loss: 2.2248 - val_accuracy: 0.3150 - val_top_k_categorical_accuracy: 0.7359
# Epoch 48/50
#  - 110s - loss: 2.2685 - accuracy: 0.3056 - top_k_categorical_accuracy: 0.7237 - val_loss: 2.2225 - val_accuracy: 0.3162 - val_top_k_categorical_accuracy: 0.7358
# Epoch 49/50
#  - 110s - loss: 2.2677 - accuracy: 0.3058 - top_k_categorical_accuracy: 0.7232 - val_loss: 2.2219 - val_accuracy: 0.3155 - val_top_k_categorical_accuracy: 0.7360
# Epoch 50/50
#  - 110s - loss: 2.2674 - accuracy: 0.3060 - top_k_categorical_accuracy: 0.7242 - val_loss: 2.2234 - val_accuracy: 0.3156 - val_top_k_categorical_accuracy: 0.7360

# %% [markdown]
# 实验五，使用BatchNormalization，不使用FilterResponseNormalization

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=50
N_HN_1=128
N_HN=128
N_LAYERS=1
N_BATCH=64
dp=0.5
Rate_Val=0.5
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
# model.add(Dense(N_HN_1,input_dim=input_dim))
# model.add(PReLU())
# model.add(Dropout(dp))
# for i in range(N_LAYERS):
#     model.add(Dense(N_HN))
#     model.add(PReLU())
#     model.add(BatchNormalization())   
#     model.add(Dropout(dp))
# model.add(Dense(output_dim))
# model.add(Activation('softmax'))
# model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])

model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
# model.add(Dropout(dp))
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
#   model.add(Dropout(dp))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
# model = multi_gpu_model(model, 2)gfyht76```
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])



# x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)
# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####


# y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
# y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
# fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)

# acc_test, test_score,fitting, model = build_and_fit_model(features_train.values,labels_train,x_val=features_test.values,y_test=labels_test,hn=N_HN,layers=N_LAYERS,epochs=N_EPOCHS,verbose=2,dp=DP)
model.save('jjs_model_0124V5.h5')
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS2.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC2.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC2.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 406265 samples, validate on 406264 samples
# Epoch 1/50
#  - 157s - loss: 2.3069 - accuracy: 0.3018 - top_k_categorical_accuracy: 0.7149 - val_loss: 2.2436 - val_accuracy: 0.3107 - val_top_k_categorical_accuracy: 0.7318
# Epoch 2/50
#  - 161s - loss: 2.2334 - accuracy: 0.3116 - top_k_categorical_accuracy: 0.7326 - val_loss: 2.2271 - val_accuracy: 0.3135 - val_top_k_categorical_accuracy: 0.7356
# Epoch 3/50
#  - 161s - loss: 2.2190 - accuracy: 0.3145 - top_k_categorical_accuracy: 0.7362 - val_loss: 2.2194 - val_accuracy: 0.3156 - val_top_k_categorical_accuracy: 0.7363
# Epoch 4/50
#  - 161s - loss: 2.2103 - accuracy: 0.3163 - top_k_categorical_accuracy: 0.7385 - val_loss: 2.2151 - val_accuracy: 0.3155 - val_top_k_categorical_accuracy: 0.7379
# Epoch 5/50
#  - 159s - loss: 2.2045 - accuracy: 0.3184 - top_k_categorical_accuracy: 0.7405 - val_loss: 2.2127 - val_accuracy: 0.3172 - val_top_k_categorical_accuracy: 0.7387
# Epoch 6/50
#  - 161s - loss: 2.1996 - accuracy: 0.3186 - top_k_categorical_accuracy: 0.7411 - val_loss: 2.2121 - val_accuracy: 0.3164 - val_top_k_categorical_accuracy: 0.7387
# Epoch 7/50
#  - 160s - loss: 2.1957 - accuracy: 0.3195 - top_k_categorical_accuracy: 0.7424 - val_loss: 2.2109 - val_accuracy: 0.3162 - val_top_k_categorical_accuracy: 0.7391
# Epoch 8/50
#  - 160s - loss: 2.1928 - accuracy: 0.3197 - top_k_categorical_accuracy: 0.7431 - val_loss: 2.2096 - val_accuracy: 0.3165 - val_top_k_categorical_accuracy: 0.7398
# Epoch 9/50
#  - 159s - loss: 2.1892 - accuracy: 0.3211 - top_k_categorical_accuracy: 0.7444 - val_loss: 2.2088 - val_accuracy: 0.3179 - val_top_k_categorical_accuracy: 0.7397
# Epoch 10/50
#  - 159s - loss: 2.1861 - accuracy: 0.3215 - top_k_categorical_accuracy: 0.7447 - val_loss: 2.2111 - val_accuracy: 0.3168 - val_top_k_categorical_accuracy: 0.7400
# Epoch 11/50
#  - 158s - loss: 2.1839 - accuracy: 0.3217 - top_k_categorical_accuracy: 0.7453 - val_loss: 2.2092 - val_accuracy: 0.3171 - val_top_k_categorical_accuracy: 0.7399
# Epoch 12/50
#  - 161s - loss: 2.1821 - accuracy: 0.3218 - top_k_categorical_accuracy: 0.7463 - val_loss: 2.2089 - val_accuracy: 0.3179 - val_top_k_categorical_accuracy: 0.7392
# Epoch 13/50
#  - 161s - loss: 2.1800 - accuracy: 0.3226 - top_k_categorical_accuracy: 0.7461 - val_loss: 2.2088 - val_accuracy: 0.3176 - val_top_k_categorical_accuracy: 0.7401
# Epoch 14/50
#  - 160s - loss: 2.1781 - accuracy: 0.3222 - top_k_categorical_accuracy: 0.7465 - val_loss: 2.2090 - val_accuracy: 0.3178 - val_top_k_categorical_accuracy: 0.7395
# Epoch 15/50
#  - 161s - loss: 2.1761 - accuracy: 0.3235 - top_k_categorical_accuracy: 0.7478 - val_loss: 2.2109 - val_accuracy: 0.3181 - val_top_k_categorical_accuracy: 0.7389
# Epoch 16/50
#  - 160s - loss: 2.1747 - accuracy: 0.3232 - top_k_categorical_accuracy: 0.7484 - val_loss: 2.2093 - val_accuracy: 0.3176 - val_top_k_categorical_accuracy: 0.7394
# Epoch 17/50
#  - 161s - loss: 2.1735 - accuracy: 0.3246 - top_k_categorical_accuracy: 0.7478 - val_loss: 2.2105 - val_accuracy: 0.3178 - val_top_k_categorical_accuracy: 0.7385
# Epoch 18/50
#  - 160s - loss: 2.1716 - accuracy: 0.3238 - top_k_categorical_accuracy: 0.7483 - val_loss: 2.2106 - val_accuracy: 0.3181 - val_top_k_categorical_accuracy: 0.7391
# Epoch 19/50
#  - 160s - loss: 2.1712 - accuracy: 0.3240 - top_k_categorical_accuracy: 0.7485 - val_loss: 2.2099 - val_accuracy: 0.3181 - val_top_k_categorical_accuracy: 0.7389
# Epoch 20/50
#  - 160s - loss: 2.1695 - accuracy: 0.3243 - top_k_categorical_accuracy: 0.7487 - val_loss: 2.2111 - val_accuracy: 0.3173 - val_top_k_categorical_accuracy: 0.7394
# Epoch 21/50
#  - 159s - loss: 2.1690 - accuracy: 0.3250 - top_k_categorical_accuracy: 0.7491 - val_loss: 2.2119 - val_accuracy: 0.3178 - val_top_k_categorical_accuracy: 0.7390
# Epoch 22/50
#  - 160s - loss: 2.1678 - accuracy: 0.3254 - top_k_categorical_accuracy: 0.7494 - val_loss: 2.2106 - val_accuracy: 0.3177 - val_top_k_categorical_accuracy: 0.7393
# Epoch 23/50
#  - 156s - loss: 2.1664 - accuracy: 0.3254 - top_k_categorical_accuracy: 0.7499 - val_loss: 2.2125 - val_accuracy: 0.3180 - val_top_k_categorical_accuracy: 0.7392
# Epoch 24/50
#  - 159s - loss: 2.1656 - accuracy: 0.3258 - top_k_categorical_accuracy: 0.7502 - val_loss: 2.2140 - val_accuracy: 0.3169 - val_top_k_categorical_accuracy: 0.7387
# Epoch 25/50
#  - 160s - loss: 2.1648 - accuracy: 0.3257 - top_k_categorical_accuracy: 0.7499 - val_loss: 2.2115 - val_accuracy: 0.3173 - val_top_k_categorical_accuracy: 0.7392
# Epoch 26/50
#  - 160s - loss: 2.1632 - accuracy: 0.3260 - top_k_categorical_accuracy: 0.7508 - val_loss: 2.2135 - val_accuracy: 0.3170 - val_top_k_categorical_accuracy: 0.7388
# Epoch 27/50
#  - 160s - loss: 2.1635 - accuracy: 0.3256 - top_k_categorical_accuracy: 0.7509 - val_loss: 2.2138 - val_accuracy: 0.3168 - val_top_k_categorical_accuracy: 0.7386
# Epoch 28/50
#  - 158s - loss: 2.1627 - accuracy: 0.3254 - top_k_categorical_accuracy: 0.7501 - val_loss: 2.2150 - val_accuracy: 0.3165 - val_top_k_categorical_accuracy: 0.7386
# Epoch 29/50
#  - 160s - loss: 2.1619 - accuracy: 0.3267 - top_k_categorical_accuracy: 0.7509 - val_loss: 2.2142 - val_accuracy: 0.3172 - val_top_k_categorical_accuracy: 0.7389
# Epoch 30/50
#  - 160s - loss: 2.1612 - accuracy: 0.3258 - top_k_categorical_accuracy: 0.7508 - val_loss: 2.2149 - val_accuracy: 0.3165 - val_top_k_categorical_accuracy: 0.7376
# Epoch 31/50
#  - 161s - loss: 2.1600 - accuracy: 0.3272 - top_k_categorical_accuracy: 0.7510 - val_loss: 2.2145 - val_accuracy: 0.3172 - val_top_k_categorical_accuracy: 0.7377
# Epoch 32/50
#  - 161s - loss: 2.1596 - accuracy: 0.3273 - top_k_categorical_accuracy: 0.7519 - val_loss: 2.2144 - val_accuracy: 0.3159 - val_top_k_categorical_accuracy: 0.7379
# Epoch 33/50
#  - 161s - loss: 2.1593 - accuracy: 0.3269 - top_k_categorical_accuracy: 0.7512 - val_loss: 2.2152 - val_accuracy: 0.3173 - val_top_k_categorical_accuracy: 0.7381
# Epoch 34/50
#  - 161s - loss: 2.1589 - accuracy: 0.3267 - top_k_categorical_accuracy: 0.7517 - val_loss: 2.2143 - val_accuracy: 0.3175 - val_top_k_categorical_accuracy: 0.7381
# Epoch 35/50
#  - 161s - loss: 2.1584 - accuracy: 0.3270 - top_k_categorical_accuracy: 0.7518 - val_loss: 2.2155 - val_accuracy: 0.3170 - val_top_k_categorical_accuracy: 0.7383
# Epoch 36/50
#  - 161s - loss: 2.1573 - accuracy: 0.3274 - top_k_categorical_accuracy: 0.7521 - val_loss: 2.2149 - val_accuracy: 0.3171 - val_top_k_categorical_accuracy: 0.7381
# Epoch 37/50
#  - 161s - loss: 2.1571 - accuracy: 0.3273 - top_k_categorical_accuracy: 0.7522 - val_loss: 2.2172 - val_accuracy: 0.3167 - val_top_k_categorical_accuracy: 0.7378
# Epoch 38/50
#  - 162s - loss: 2.1566 - accuracy: 0.3272 - top_k_categorical_accuracy: 0.7520 - val_loss: 2.2162 - val_accuracy: 0.3173 - val_top_k_categorical_accuracy: 0.7377
# Epoch 39/50
#  - 160s - loss: 2.1561 - accuracy: 0.3275 - top_k_categorical_accuracy: 0.7526 - val_loss: 2.2162 - val_accuracy: 0.3178 - val_top_k_categorical_accuracy: 0.7378
# Epoch 40/50
#  - 161s - loss: 2.1554 - accuracy: 0.3281 - top_k_categorical_accuracy: 0.7528 - val_loss: 2.2170 - val_accuracy: 0.3162 - val_top_k_categorical_accuracy: 0.7375
# Epoch 41/50
#  - 160s - loss: 2.1551 - accuracy: 0.3272 - top_k_categorical_accuracy: 0.7525 - val_loss: 2.2175 - val_accuracy: 0.3163 - val_top_k_categorical_accuracy: 0.7378
# Epoch 42/50
#  - 161s - loss: 2.1549 - accuracy: 0.3275 - top_k_categorical_accuracy: 0.7526 - val_loss: 2.2181 - val_accuracy: 0.3164 - val_top_k_categorical_accuracy: 0.7375
# Epoch 43/50
#  - 161s - loss: 2.1543 - accuracy: 0.3278 - top_k_categorical_accuracy: 0.7524 - val_loss: 2.2187 - val_accuracy: 0.3162 - val_top_k_categorical_accuracy: 0.7370
# Epoch 44/50
#  - 161s - loss: 2.1534 - accuracy: 0.3286 - top_k_categorical_accuracy: 0.7526 - val_loss: 2.2180 - val_accuracy: 0.3169 - val_top_k_categorical_accuracy: 0.7377
# Epoch 45/50
#  - 161s - loss: 2.1533 - accuracy: 0.3279 - top_k_categorical_accuracy: 0.7532 - val_loss: 2.2189 - val_accuracy: 0.3151 - val_top_k_categorical_accuracy: 0.7371
# Epoch 46/50
#  - 160s - loss: 2.1530 - accuracy: 0.3281 - top_k_categorical_accuracy: 0.7528 - val_loss: 2.2190 - val_accuracy: 0.3165 - val_top_k_categorical_accuracy: 0.7379
# Epoch 47/50
#  - 161s - loss: 2.1528 - accuracy: 0.3277 - top_k_categorical_accuracy: 0.7528 - val_loss: 2.2187 - val_accuracy: 0.3158 - val_top_k_categorical_accuracy: 0.7373
# Epoch 48/50
#  - 161s - loss: 2.1521 - accuracy: 0.3282 - top_k_categorical_accuracy: 0.7529 - val_loss: 2.2199 - val_accuracy: 0.3163 - val_top_k_categorical_accuracy: 0.7374
# Epoch 49/50
#  - 159s - loss: 2.1523 - accuracy: 0.3283 - top_k_categorical_accuracy: 0.7529 - val_loss: 2.2190 - val_accuracy: 0.3158 - val_top_k_categorical_accuracy: 0.7374
# Epoch 50/50
#  - 160s - loss: 2.1516 - accuracy: 0.3288 - top_k_categorical_accuracy: 0.7535 - val_loss: 2.2183 - val_accuracy: 0.3158 - val_top_k_categorical_accuracy: 0.7376

# %% [markdown]
# 实验六、在试验五的基础上搞大神经网络

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=40
N_HN_1=256
N_HN=128
N_LAYERS=2
N_BATCH=64
Rate_Val=0.5
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
# model.add(Dense(N_HN_1,input_dim=input_dim))
# model.add(PReLU())
# model.add(Dropout(dp))
# for i in range(N_LAYERS):
#     model.add(Dense(N_HN))
#     model.add(PReLU())
#     model.add(BatchNormalization())   
#     model.add(Dropout(dp))
# model.add(Dense(output_dim))
# model.add(Activation('softmax'))
# model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])

model.add(Dense(N_HN_1,input_dim=input_dim))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
# model.add(Dropout(dp))
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
    model.add(BatchNormalization())   
    #model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
#   model.add(Dropout(dp))
model.add(BatchNormalization())
# model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
# model = multi_gpu_model(model, 2)gfyht76```
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])

# x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)
# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####


# y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
# y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
# fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)

# acc_test, test_score,fitting, model = build_and_fit_model(features_train.values,labels_train,x_val=features_test.values,y_test=labels_test,hn=N_HN,layers=N_LAYERS,epochs=N_EPOCHS,verbose=2,dp=DP)
model.save('jjs_model_0124V5.h5')
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS2.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC2.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC2.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 406265 samples, validate on 406264 samples
# Epoch 1/40
#  - 194s - loss: 2.3070 - accuracy: 0.3006 - top_k_categorical_accuracy: 0.7155 - val_loss: 2.2409 - val_accuracy: 0.3117 - val_top_k_categorical_accuracy: 0.7301
# Epoch 2/40
#  - 191s - loss: 2.2352 - accuracy: 0.3108 - top_k_categorical_accuracy: 0.7329 - val_loss: 2.2277 - val_accuracy: 0.3133 - val_top_k_categorical_accuracy: 0.7344
# Epoch 3/40
#  - 192s - loss: 2.2181 - accuracy: 0.3153 - top_k_categorical_accuracy: 0.7368 - val_loss: 2.2193 - val_accuracy: 0.3143 - val_top_k_categorical_accuracy: 0.7373
# Epoch 4/40
#  - 194s - loss: 2.2073 - accuracy: 0.3174 - top_k_categorical_accuracy: 0.7394 - val_loss: 2.2140 - val_accuracy: 0.3166 - val_top_k_categorical_accuracy: 0.7384
# Epoch 5/40
#  - 192s - loss: 2.1986 - accuracy: 0.3188 - top_k_categorical_accuracy: 0.7420 - val_loss: 2.2095 - val_accuracy: 0.3185 - val_top_k_categorical_accuracy: 0.7397
# Epoch 6/40
#  - 193s - loss: 2.1914 - accuracy: 0.3202 - top_k_categorical_accuracy: 0.7441 - val_loss: 2.2130 - val_accuracy: 0.3159 - val_top_k_categorical_accuracy: 0.7383
# Epoch 7/40
#  - 193s - loss: 2.1854 - accuracy: 0.3221 - top_k_categorical_accuracy: 0.7454 - val_loss: 2.2088 - val_accuracy: 0.3179 - val_top_k_categorical_accuracy: 0.7398
# Epoch 8/40
#  - 193s - loss: 2.1799 - accuracy: 0.3232 - top_k_categorical_accuracy: 0.7468 - val_loss: 2.2081 - val_accuracy: 0.3179 - val_top_k_categorical_accuracy: 0.7401
# Epoch 9/40
#  - 192s - loss: 2.1742 - accuracy: 0.3245 - top_k_categorical_accuracy: 0.7483 - val_loss: 2.2115 - val_accuracy: 0.3171 - val_top_k_categorical_accuracy: 0.7390
# Epoch 10/40
#  - 192s - loss: 2.1692 - accuracy: 0.3253 - top_k_categorical_accuracy: 0.7497 - val_loss: 2.2123 - val_accuracy: 0.3173 - val_top_k_categorical_accuracy: 0.7384
# Epoch 11/40
#  - 191s - loss: 2.1650 - accuracy: 0.3259 - top_k_categorical_accuracy: 0.7504 - val_loss: 2.2133 - val_accuracy: 0.3162 - val_top_k_categorical_accuracy: 0.7385
# Epoch 12/40
#  - 191s - loss: 2.1605 - accuracy: 0.3277 - top_k_categorical_accuracy: 0.7521 - val_loss: 2.2160 - val_accuracy: 0.3166 - val_top_k_categorical_accuracy: 0.7386
# Epoch 13/40
#  - 192s - loss: 2.1563 - accuracy: 0.3279 - top_k_categorical_accuracy: 0.7534 - val_loss: 2.2172 - val_accuracy: 0.3171 - val_top_k_categorical_accuracy: 0.7375
# Epoch 14/40
#  - 187s - loss: 2.1525 - accuracy: 0.3278 - top_k_categorical_accuracy: 0.7536 - val_loss: 2.2183 - val_accuracy: 0.3170 - val_top_k_categorical_accuracy: 0.7373
# Epoch 15/40
#  - 191s - loss: 2.1488 - accuracy: 0.3295 - top_k_categorical_accuracy: 0.7551 - val_loss: 2.2185 - val_accuracy: 0.3166 - val_top_k_categorical_accuracy: 0.7365
# Epoch 16/40
#  - 193s - loss: 2.1465 - accuracy: 0.3301 - top_k_categorical_accuracy: 0.7556 - val_loss: 2.2221 - val_accuracy: 0.3147 - val_top_k_categorical_accuracy: 0.7359
# Epoch 17/40
#  - 192s - loss: 2.1431 - accuracy: 0.3299 - top_k_categorical_accuracy: 0.7569 - val_loss: 2.2211 - val_accuracy: 0.3161 - val_top_k_categorical_accuracy: 0.7361
# Epoch 18/40
#  - 192s - loss: 2.1403 - accuracy: 0.3310 - top_k_categorical_accuracy: 0.7575 - val_loss: 2.2237 - val_accuracy: 0.3151 - val_top_k_categorical_accuracy: 0.7355
# Epoch 19/40
#  - 195s - loss: 2.1366 - accuracy: 0.3318 - top_k_categorical_accuracy: 0.7580 - val_loss: 2.2255 - val_accuracy: 0.3155 - val_top_k_categorical_accuracy: 0.7355
# Epoch 20/40
#  - 193s - loss: 2.1343 - accuracy: 0.3324 - top_k_categorical_accuracy: 0.7584 - val_loss: 2.2301 - val_accuracy: 0.3143 - val_top_k_categorical_accuracy: 0.7345
# Epoch 21/40
#  - 193s - loss: 2.1327 - accuracy: 0.3324 - top_k_categorical_accuracy: 0.7591 - val_loss: 2.2294 - val_accuracy: 0.3149 - val_top_k_categorical_accuracy: 0.7343
# Epoch 22/40
#  - 194s - loss: 2.1305 - accuracy: 0.3328 - top_k_categorical_accuracy: 0.7595 - val_loss: 2.2294 - val_accuracy: 0.3151 - val_top_k_categorical_accuracy: 0.7346
# Epoch 23/40
#  - 194s - loss: 2.1266 - accuracy: 0.3334 - top_k_categorical_accuracy: 0.7606 - val_loss: 2.2326 - val_accuracy: 0.3133 - val_top_k_categorical_accuracy: 0.7333
# Epoch 24/40
#  - 193s - loss: 2.1252 - accuracy: 0.3339 - top_k_categorical_accuracy: 0.7612 - val_loss: 2.2339 - val_accuracy: 0.3138 - val_top_k_categorical_accuracy: 0.7333
# Epoch 25/40
#  - 194s - loss: 2.1228 - accuracy: 0.3341 - top_k_categorical_accuracy: 0.7614 - val_loss: 2.2365 - val_accuracy: 0.3134 - val_top_k_categorical_accuracy: 0.7327
# Epoch 26/40
#  - 192s - loss: 2.1213 - accuracy: 0.3337 - top_k_categorical_accuracy: 0.7624 - val_loss: 2.2366 - val_accuracy: 0.3138 - val_top_k_categorical_accuracy: 0.7325
# Epoch 27/40
#  - 193s - loss: 2.1181 - accuracy: 0.3352 - top_k_categorical_accuracy: 0.7633 - val_loss: 2.2397 - val_accuracy: 0.3122 - val_top_k_categorical_accuracy: 0.7315
# Epoch 28/40
#  - 193s - loss: 2.1175 - accuracy: 0.3357 - top_k_categorical_accuracy: 0.7627 - val_loss: 2.2440 - val_accuracy: 0.3103 - val_top_k_categorical_accuracy: 0.7308
# Epoch 29/40
#  - 191s - loss: 2.1154 - accuracy: 0.3358 - top_k_categorical_accuracy: 0.7634 - val_loss: 2.2410 - val_accuracy: 0.3134 - val_top_k_categorical_accuracy: 0.7319
# Epoch 30/40
#  - 193s - loss: 2.1144 - accuracy: 0.3354 - top_k_categorical_accuracy: 0.7638 - val_loss: 2.2429 - val_accuracy: 0.3131 - val_top_k_categorical_accuracy: 0.7316
# Epoch 31/40
#  - 193s - loss: 2.1122 - accuracy: 0.3365 - top_k_categorical_accuracy: 0.7644 - val_loss: 2.2424 - val_accuracy: 0.3109 - val_top_k_categorical_accuracy: 0.7313
# Epoch 32/40
#  - 194s - loss: 2.1107 - accuracy: 0.3368 - top_k_categorical_accuracy: 0.7649 - val_loss: 2.2451 - val_accuracy: 0.3129 - val_top_k_categorical_accuracy: 0.7319
# Epoch 33/40
#  - 191s - loss: 2.1087 - accuracy: 0.3362 - top_k_categorical_accuracy: 0.7657 - val_loss: 2.2467 - val_accuracy: 0.3119 - val_top_k_categorical_accuracy: 0.7304
# Epoch 34/40
#  - 190s - loss: 2.1076 - accuracy: 0.3377 - top_k_categorical_accuracy: 0.7650 - val_loss: 2.2492 - val_accuracy: 0.3112 - val_top_k_categorical_accuracy: 0.7301
# Epoch 35/40
#  - 189s - loss: 2.1064 - accuracy: 0.3377 - top_k_categorical_accuracy: 0.7663 - val_loss: 2.2490 - val_accuracy: 0.3118 - val_top_k_categorical_accuracy: 0.7304
# Epoch 36/40
#  - 192s - loss: 2.1047 - accuracy: 0.3377 - top_k_categorical_accuracy: 0.7661 - val_loss: 2.2501 - val_accuracy: 0.3104 - val_top_k_categorical_accuracy: 0.7286
# Epoch 37/40
#  - 192s - loss: 2.1035 - accuracy: 0.3383 - top_k_categorical_accuracy: 0.7662 - val_loss: 2.2492 - val_accuracy: 0.3128 - val_top_k_categorical_accuracy: 0.7305
# Epoch 38/40
#  - 192s - loss: 2.1016 - accuracy: 0.3389 - top_k_categorical_accuracy: 0.7664 - val_loss: 2.2519 - val_accuracy: 0.3120 - val_top_k_categorical_accuracy: 0.7306
# Epoch 39/40
#  - 192s - loss: 2.1013 - accuracy: 0.3381 - top_k_categorical_accuracy: 0.7666 - val_loss: 2.2527 - val_accuracy: 0.3100 - val_top_k_categorical_accuracy: 0.7294
# Epoch 40/40
#  - 192s - loss: 2.1003 - accuracy: 0.3383 - top_k_categorical_accuracy: 0.7680 - val_loss: 2.2534 - val_accuracy: 0.3106 - val_top_k_categorical_accuracy: 0.7299

# %% [markdown]
# 实验七、在实验六的基础上改为FilterResponseNormalization

# %%
####TEST DNN
print('------------Building DNN model--------------')
ShuffleInTraining=True
N_EPOCHS=30
N_HN_1=256
N_HN=128
N_LAYERS=2
N_BATCH=64
dp=0.5
Rate_Val=0.5
N_Val_OverSampler=int(np.around(N_AllTrain_OverSampler*Rate_Val))
N_Train_OverSampler=int(N_AllTrain_OverSampler-N_Val_OverSampler)
N_CLASS=len(allDF["Category"].unique())
input_dim=featuresArrayOverSampler.shape[1]
output_dim=N_CLASS

model = Sequential()
model.add(Dense(N_HN_1,input_dim=input_dim))
# model.add(BatchNormalization())
model.add(FilterResponseNormalization(axis=None))
model.add(PReLU())
for i in range(N_LAYERS):
    model.add(Dense(N_HN))
#     model.add(BatchNormalization())   
    model.add(FilterResponseNormalization(axis=None))
    model.add(PReLU())
#   model.add(Dropout(dp))
# model.add(BatchNormalization())
model.add(FilterResponseNormalization(axis=None))
model.add(Dense(output_dim))
model.add(Activation('softmax'))
# model = multi_gpu_model(model, 2)
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy', metrics.top_k_categorical_accuracy])

# x_train,x_val,y_train,y_val = train_test_split(featuresArrayOverSampler,labelsArrayOverSampler,test_size=N_Val_OverSampler,train_size=N_Train_OverSampler, shuffle=True)
# ros_train = RandomOverSampler()
# x_train, y_train = ros_train.fit_resample(x_train,y_train)#####过采样#####
# ros_val = RandomOverSampler()
# x_val, y_val = ros_val.fit_resample(x_val,y_val)#####过采样#####


# y_train = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_train)), num_classes=N_CLASS)
# y_val = keras.utils.to_categorical(LabelEncoder().fit_transform(np.array(y_val)), num_classes=N_CLASS)
print('------------DNN Training Go! Go! Go!!!!-----------')
# fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)
fitting=model.fit(x_train, y_train, epochs=N_EPOCHS, batch_size=N_BATCH,verbose=2,validation_data=(x_val,y_val),shuffle=True)

# acc_test, test_score,fitting, model = build_and_fit_model(features_train.values,labels_train,x_val=features_test.values,y_test=labels_test,hn=N_HN,layers=N_LAYERS,epochs=N_EPOCHS,verbose=2,dp=DP)
model.save('jjs_model_0124V5.h5')
loss = fitting.history['loss']
val_loss = fitting.history['val_loss']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'ro', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_LOSS2.png')
plt.show()

top_acc_train=fitting.history['accuracy']
top_acc=fitting.history['val_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top_acc_train, 'bo', label='Train top acc')
plt.plot(epochs, top_acc, 'ro', label='Val top acc')
plt.title('Training and validation ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_ACC2.png')
plt.show()

top5_acc_train=fitting.history['top_k_categorical_accuracy']
top5_acc=fitting.history['val_top_k_categorical_accuracy']
epochs = range(len(loss))
plt.figure(figsize=(7,4))
plt.plot(epochs, top5_acc_train, 'bo', label='Train top 5 acc')
plt.plot(epochs, top5_acc, 'ro', label='Val top 5 acc')
plt.title('Training and validation TOP5_ACC')
plt.legend()
plt.grid() 
plt.savefig('./Batc64HN128_64_Ep30_TOP5ACC2.png')
plt.show()
# Out:
# ------------Building DNN model--------------
# ------------DNN Training Go! Go! Go!!!!-----------
# Train on 406265 samples, validate on 406264 samples
# Epoch 1/30
#  - 148s - loss: 2.2954 - accuracy: 0.3021 - top_k_categorical_accuracy: 0.7157 - val_loss: 2.2528 - val_accuracy: 0.3103 - val_top_k_categorical_accuracy: 0.7300
# Epoch 2/30
#  - 147s - loss: 2.2261 - accuracy: 0.3150 - top_k_categorical_accuracy: 0.7349 - val_loss: 2.2273 - val_accuracy: 0.3141 - val_top_k_categorical_accuracy: 0.7362
# Epoch 3/30
#  - 145s - loss: 2.2083 - accuracy: 0.3180 - top_k_categorical_accuracy: 0.7396 - val_loss: 2.2209 - val_accuracy: 0.3153 - val_top_k_categorical_accuracy: 0.7364
# Epoch 4/30
#  - 145s - loss: 2.1960 - accuracy: 0.3205 - top_k_categorical_accuracy: 0.7431 - val_loss: 2.2177 - val_accuracy: 0.3159 - val_top_k_categorical_accuracy: 0.7378
# Epoch 5/30
#  - 145s - loss: 2.1864 - accuracy: 0.3229 - top_k_categorical_accuracy: 0.7460 - val_loss: 2.2145 - val_accuracy: 0.3168 - val_top_k_categorical_accuracy: 0.7387
# Epoch 6/30
#  - 146s - loss: 2.1785 - accuracy: 0.3240 - top_k_categorical_accuracy: 0.7476 - val_loss: 2.2114 - val_accuracy: 0.3176 - val_top_k_categorical_accuracy: 0.7390
# Epoch 7/30
#  - 146s - loss: 2.1708 - accuracy: 0.3255 - top_k_categorical_accuracy: 0.7490 - val_loss: 2.2121 - val_accuracy: 0.3180 - val_top_k_categorical_accuracy: 0.7394
# Epoch 8/30
#  - 145s - loss: 2.1638 - accuracy: 0.3275 - top_k_categorical_accuracy: 0.7507 - val_loss: 2.2136 - val_accuracy: 0.3170 - val_top_k_categorical_accuracy: 0.7380
# Epoch 9/30
#  - 146s - loss: 2.1574 - accuracy: 0.3291 - top_k_categorical_accuracy: 0.7531 - val_loss: 2.2127 - val_accuracy: 0.3177 - val_top_k_categorical_accuracy: 0.7379
# Epoch 10/30
#  - 145s - loss: 2.1512 - accuracy: 0.3309 - top_k_categorical_accuracy: 0.7542 - val_loss: 2.2151 - val_accuracy: 0.3177 - val_top_k_categorical_accuracy: 0.7381
# Epoch 11/30
#  - 144s - loss: 2.1455 - accuracy: 0.3309 - top_k_categorical_accuracy: 0.7553 - val_loss: 2.2223 - val_accuracy: 0.3157 - val_top_k_categorical_accuracy: 0.7364
# Epoch 12/30
#  - 145s - loss: 2.1398 - accuracy: 0.3329 - top_k_categorical_accuracy: 0.7574 - val_loss: 2.2212 - val_accuracy: 0.3161 - val_top_k_categorical_accuracy: 0.7368
# Epoch 13/30
#  - 144s - loss: 2.1346 - accuracy: 0.3337 - top_k_categorical_accuracy: 0.7588 - val_loss: 2.2225 - val_accuracy: 0.3161 - val_top_k_categorical_accuracy: 0.7369
# Epoch 14/30
#  - 145s - loss: 2.1301 - accuracy: 0.3352 - top_k_categorical_accuracy: 0.7599 - val_loss: 2.2251 - val_accuracy: 0.3154 - val_top_k_categorical_accuracy: 0.7359
# Epoch 15/30
#  - 144s - loss: 2.1250 - accuracy: 0.3359 - top_k_categorical_accuracy: 0.7609 - val_loss: 2.2299 - val_accuracy: 0.3152 - val_top_k_categorical_accuracy: 0.7353
# Epoch 16/30
#  - 145s - loss: 2.1204 - accuracy: 0.3369 - top_k_categorical_accuracy: 0.7622 - val_loss: 2.2314 - val_accuracy: 0.3154 - val_top_k_categorical_accuracy: 0.7352
# Epoch 17/30
#  - 145s - loss: 2.1162 - accuracy: 0.3380 - top_k_categorical_accuracy: 0.7634 - val_loss: 2.2341 - val_accuracy: 0.3139 - val_top_k_categorical_accuracy: 0.7340
# Epoch 18/30
#  - 145s - loss: 2.1120 - accuracy: 0.3388 - top_k_categorical_accuracy: 0.7642 - val_loss: 2.2388 - val_accuracy: 0.3133 - val_top_k_categorical_accuracy: 0.7332
# Epoch 19/30
#  - 145s - loss: 2.1082 - accuracy: 0.3399 - top_k_categorical_accuracy: 0.7656 - val_loss: 2.2446 - val_accuracy: 0.3121 - val_top_k_categorical_accuracy: 0.7321
# Epoch 20/30
#  - 145s - loss: 2.1042 - accuracy: 0.3403 - top_k_categorical_accuracy: 0.7664 - val_loss: 2.2431 - val_accuracy: 0.3115 - val_top_k_categorical_accuracy: 0.7319
# Epoch 21/30
#  - 146s - loss: 2.1004 - accuracy: 0.3420 - top_k_categorical_accuracy: 0.7670 - val_loss: 2.2483 - val_accuracy: 0.3097 - val_top_k_categorical_accuracy: 0.7311
# Epoch 22/30
#  - 145s - loss: 2.0967 - accuracy: 0.3425 - top_k_categorical_accuracy: 0.7681 - val_loss: 2.2461 - val_accuracy: 0.3116 - val_top_k_categorical_accuracy: 0.7316
# Epoch 23/30
#  - 144s - loss: 2.0935 - accuracy: 0.3429 - top_k_categorical_accuracy: 0.7693 - val_loss: 2.2471 - val_accuracy: 0.3116 - val_top_k_categorical_accuracy: 0.7310
# Epoch 24/30
#  - 145s - loss: 2.0903 - accuracy: 0.3434 - top_k_categorical_accuracy: 0.7699 - val_loss: 2.2531 - val_accuracy: 0.3103 - val_top_k_categorical_accuracy: 0.7293
# Epoch 25/30
#  - 145s - loss: 2.0872 - accuracy: 0.3444 - top_k_categorical_accuracy: 0.7707 - val_loss: 2.2594 - val_accuracy: 0.3110 - val_top_k_categorical_accuracy: 0.7301
# Epoch 26/30
#  - 146s - loss: 2.0838 - accuracy: 0.3451 - top_k_categorical_accuracy: 0.7714 - val_loss: 2.2547 - val_accuracy: 0.3105 - val_top_k_categorical_accuracy: 0.7295
# Epoch 27/30
#  - 147s - loss: 2.0808 - accuracy: 0.3459 - top_k_categorical_accuracy: 0.7720 - val_loss: 2.2683 - val_accuracy: 0.3101 - val_top_k_categorical_accuracy: 0.7296
# Epoch 28/30
#  - 145s - loss: 2.0778 - accuracy: 0.3465 - top_k_categorical_accuracy: 0.7726 - val_loss: 2.2632 - val_accuracy: 0.3099 - val_top_k_categorical_accuracy: 0.7299
# Epoch 29/30
#  - 147s - loss: 2.0755 - accuracy: 0.3471 - top_k_categorical_accuracy: 0.7740 - val_loss: 2.2644 - val_accuracy: 0.3079 - val_top_k_categorical_accuracy: 0.7271
# Epoch 30/30
#  - 145s - loss: 2.0726 - accuracy: 0.3473 - top_k_categorical_accuracy: 0.7749 - val_loss: 2.2724 - val_accuracy: 0.3083 - val_top_k_categorical_accuracy: 0.7277

# %%
import tensorflow as tf
from keras import backend as K
 
K.clear_session()
tf.reset_default_graph()
